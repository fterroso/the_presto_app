# %%
import pandas as pd
import numpy as np
import os 
from datetime import datetime,timedelta
from dateutil.relativedelta import relativedelta

import torch
import torch_geometric
from tqdm.notebook import tqdm
import copy
from typing import List, Optional, Tuple, Union

from torch import Tensor

from torch_geometric.utils.mask import index_to_mask
from torch_geometric.utils.num_nodes import maybe_num_nodes
from torch_geometric.typing import OptTensor, PairTensor
from torch_geometric.loader import LinkNeighborLoader, NeighborLoader
from torch_geometric.data import HeteroData
from torch_geometric_temporal.nn.hetero.heterogclstm import HeteroGCLSTM
from torch_geometric.nn import SAGEConv, GATv2Conv
import torch.nn.functional as F
from torch_geometric.nn.norm import BatchNorm
from torch.nn import Module, ModuleDict
from torch_geometric.nn import to_hetero
#from torch_geometric.utils import bipartite_subgraph
from ast import literal_eval

from sklearn.manifold import TSNE
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score

# %%
print(torch.__version__)
# Out:
# 1.13.1+cpu

# %%
print(torch_geometric.__version__)
# Out:
# 2.2.0

# %%
init_date='2004-01-01'
final_date='2021-12-31'
init_date_obj = datetime.strptime(init_date, '%Y-%m-%d')
init_date_obj
# Out:
# datetime.datetime(2004, 1, 1, 0, 0)

# %%
d=init_date_obj + relativedelta(months=0)
datetime.strftime(d,'%Y-%m-%d')
# Out:
# '2004-01-01'

# %%
tracks_info= pd.read_csv(os.path.join('data', 'generated', '05b_all_tracks_w_feat_and_genre.csv'),
                         converters={"artist_id": literal_eval, 'artist_name': literal_eval, 'genres':literal_eval}, 
                         parse_dates=['release_date'],
                         index_col=0)
#tracks_info= tracks_info[(tracks_info['release_date']>init_date) & (tracks_info['release_date']<=final_date)]
#tracks_info= tracks_info[tracks_info['num_genres']>0]

tracks_info= tracks_info.reset_index(drop=True)
tracks_info['num_artists']= tracks_info['artist_id'].apply(lambda x:len(x))

# %%
collab_tracks= tracks_info[tracks_info['num_artists']>1]
collab_tracks
# Out:
#                        track_id release_date release_date_precision  \
# 1        4ak7xjvBeBOcJGWFDX9w5n   2019-06-21                    day
# 6        5ZbcYWBQWoCpuVip1fmeMY   2018-11-23                    day
# 9        0fcq51a3gOI6gPvzc0YLsk   2019-03-15                    day
# 13       3kf0ERnVuqQs62SIpj4HN8   2018-10-26                    day
# 16       3tDqEKKUs6gf8zMvSuLyLA   2020-02-28                    day
# ...                         ...          ...                    ...
# 1966466  6X2jYZpOrXiDXpOvQGcvsU   2015-02-04                    day
# 1966479  4F2faUgJBqsrgA51Lz6dNZ   2022-01-08                    day
# 1966484  0h9bMMjrFaNJP5oWMq7xPy   2018-10-19                    day
# 1966486  7iqZMtyAQrp5CnIteoonl1   1999-01-01                    day
# 1966493  7jRAM1k7NiH5wg5E9IfMOQ   2011-03-15                    day
#
#                                                  artist_id  \
# 1         [7jVv8c5Fj3E9VhNjxT4snq, 4kYSro6naA4h99UJvo89HB]
# 6         [3CJKkU0XuElRT1z8rEtIYg, 6ytOHdKh4xt4YvF7tz8Zcv]
# 9        [246dkjvS1zLTtiykXe5h60, 757aE44tKEUQEqRuT6GnE...
# 13        [6S3KljEiIOWoLMUyZrkQUc, 5uJw4WCX5nYj4FHky9r1Ug]
# 16        [5f7VJjfbwm532GiveGC0ZK, 4O15NlyKLIASxsJ0PrXPfz]
# ...                                                    ...
# 1966466   [2EWXgN0xWOnbqJOxa9pWNO, 0Pt3k7cpeOysqGGiw3tQcS]
# 1966479   [1Uff91EOsvd99rtAupatMP, 1p0J5PXJQMVqk5uVV4T1ja]
# 1966484  [1GGaiTLrRiVRnTdJygL1Yq, 6q8DZBLBYqEUdKZl54sqG...
# 1966486   [7rPqFVgJYARiFsLDlN6W6y, 5ReVxzuREWusYE4ovnMbBn]
# 1966493   [1umoTEAL97Q6OAS1KX2RX3, 3zfUeJ7cYJuM0jbKoU64Ip]
#
#                                     artist_name  danceability   energy   key  \
# 1                          [Lil Nas X, Cardi B]         0.706  0.67900   9.0
# 6                    [Luciano, Kalash Criminel]         0.825  0.62600   4.0
# 9              [Post Malone, Roddy Ricch, Tyga]         0.797  0.64000  11.0
# 13                              [Marnik, SMACK]         0.475  0.91400   0.0
# 16                     [Lil Baby, Lil Uzi Vert]         0.892  0.48600  11.0
# ...                                         ...           ...      ...   ...
# 1966466           [SawanoHiroyuki[nZk], mizuki]         0.536  0.92900   8.0
# 1966479         [Claude Debussy, Seong-Jin Cho]         0.295  0.00642   1.0
# 1966484  [LOWFi, Jayy Grams, Hayelo, Von Wilda]         0.723  0.72900   0.0
# 1966486           [Toquinho, Paulinho Nogueira]         0.696  0.26000   2.0
# 1966493                         [TV Rock, Rudy]         0.798  0.82500   8.0
#
#          loudness  mode  speechiness  acousticness  instrumentalness  \
# 1          -5.614   1.0       0.0324       0.13900          0.000070
# 6          -8.444   0.0       0.3380       0.26500          0.000025
# 9          -6.272   0.0       0.1940       0.14800          0.000000
# 13         -4.255   0.0       0.0555       0.03400          0.000202
# 16         -8.637   0.0       0.3840       0.04800          0.000000
# ...           ...   ...          ...           ...               ...
# 1966466    -4.829   1.0       0.0567       0.00542          0.000000
# 1966479   -36.008   0.0       0.0380       0.99500          0.925000
# 1966484    -4.701   1.0       0.2310       0.26500          0.000000
# 1966486   -15.253   0.0       0.0510       0.97400          0.885000
# 1966493    -5.923   1.0       0.0517       0.00366          0.806000
#
#          liveness  valence    tempo  \
# 1          0.4650    0.657  140.081
# 6          0.1010    0.642  142.995
# 9          0.2090    0.486  100.002
# 13         0.2770    0.156  138.007
# 16         0.1460    0.535  120.998
# ...           ...      ...      ...
# 1966466    0.2190    0.593  157.998
# 1966479    0.0610    0.121   77.235
# 1966484    0.1030    0.909   89.970
# 1966486    0.1100    0.271  119.838
# 1966493    0.0392    0.245  127.999
#
#                                                     genres  num_genres  \
# 1                                        [rap, dance, pop]           3
# 6                      [german, hip-hop, rap, french, pop]           5
# 9                    [rap, trap, pop, rap, dance, hip-hop]           6
# 13                                                      []           0
# 16                         [hip-hop, rap, trap, rap, trap]           5
# ...                                                    ...         ...
# 1966466                                            [anime]           1
# 1966479                      [classical, classical, piano]           3
# 1966484                                          [hip-hop]           1
# 1966486  [mpb, samba, bossa nova, choro, violao, violao...           6
# 1966493                                            [dance]           1
#
#                                                 genres_str  num_artists
# 1                                           ;rap,dance,pop            2
# 6                           ;german,hip-hop,rap,french,pop            2
# 9                          ;rap,trap,pop,rap,dance,hip-hop            3
# 13                                                       ;            2
# 16                              ;hip-hop,rap,trap,rap,trap            2
# ...                                                    ...          ...
# 1966466                                             ;anime            2
# 1966479                         ;classical,classical,piano            2
# 1966484                                           ;hip-hop            4
# 1966486  ;mpb,samba,bossa nova,choro,violao,violao clas...            2
# 1966493                                             ;dance            2
#
# [233254 rows x 20 columns]

# %%
collab_tracks[collab_tracks['artist_id'].map(lambda x: ('7jVv8c5Fj3E9VhNjxT4snq' in x) and ('4kYSro6naA4h99UJvo89HB' in x))]
# Out:
#                      track_id release_date release_date_precision  \
# 1      4ak7xjvBeBOcJGWFDX9w5n   2019-06-21                    day
# 42054  5MWOSsgPDm3aPvAHWghxxG   2019-06-21                    day
#
#                                               artist_id           artist_name  \
# 1      [7jVv8c5Fj3E9VhNjxT4snq, 4kYSro6naA4h99UJvo89HB]  [Lil Nas X, Cardi B]
# 42054  [7jVv8c5Fj3E9VhNjxT4snq, 4kYSro6naA4h99UJvo89HB]  [Lil Nas X, Cardi B]
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1             0.706   0.679  9.0    -5.614   1.0       0.0324         0.139
# 42054         0.711   0.687  9.0    -5.606   1.0       0.0318         0.138
#
#        instrumentalness  liveness  valence    tempo             genres  \
# 1              0.000070     0.465    0.657  140.081  [rap, dance, pop]
# 42054          0.000071     0.465    0.668  140.065  [rap, dance, pop]
#
#        num_genres      genres_str  num_artists
# 1               3  ;rap,dance,pop            2
# 42054           3  ;rap,dance,pop            2

# %%
df= tracks_info[tracks_info['artist_name'].map(lambda x: ('Riverside' in x))]
df[df['num_artists']>1]
# Out:
# Empty DataFrame
# Columns: [track_id, release_date, release_date_precision, artist_id, artist_name, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, genres, num_genres, genres_str, num_artists]
# Index: []

# %%
artist_info_df= pd.read_csv(os.path.join('data','generated', '04_lfm_spotify_artist_info_V2.csv'), 
                         converters={"genres": literal_eval}, index_col=0)
artist_info_df= artist_info_df.dropna(axis=0)
artist_info_df= artist_info_df.reset_index(drop=True)
artist_info_df
# Out:
#                    artist_code         artist_name  popularity  followers  \
# 0       2d6NCBac0YDM7UthnFGPYz         Strumparnir          19      641.0
# 1       1XVbGKrwpq5PkEbOX2z5mg     Lay Down Rotten           5     2288.0
# 2       4zMX9gWf1DKhvsYHUCbBF7      T Bone Burnett          31    28844.0
# 3       2eJkpFtB62y7qCx27DDNGY                Dome          10     2219.0
# 4       6XUNUZVWpFql1ysNCVvsNS         Daniel Tosh          42     6829.0
# ...                        ...                 ...         ...        ...
# 259693  4NOgfZ4g8sFOjffbwT9qee         MAD MONSTER           5      667.0
# 259694  3CZ6FxLtgdyxJgMufi2M8w  Adecvat_production          31     1346.0
# 259695  41sqYvXOn3ATsAQ65G1zx6       María Parrado          41    52785.0
# 259696  1JOZiF1pKROyjz9YGTCpAc      Hienpuicakiiis           0      635.0
# 259697  40hHMxI5E4rIoyysjqXfXI               Xenon          47    55362.0
#
#                     genres
# 0                    [pop]
# 1          [german, metal]
# 2                   [rock]
# 3                [british]
# 4                       []
# ...                    ...
# 259693                  []
# 259694               [pop]
# 259695                  []
# 259696                  []
# 259697  [spanish, hip-hop]
#
# [259698 rows x 5 columns]

# %%
artists_map= artist_info_df['artist_code'].to_dict()
artists_map
# Out:
# {0: '2d6NCBac0YDM7UthnFGPYz',
#  1: '1XVbGKrwpq5PkEbOX2z5mg',
#  2: '4zMX9gWf1DKhvsYHUCbBF7',
#  3: '2eJkpFtB62y7qCx27DDNGY',
#  4: '6XUNUZVWpFql1ysNCVvsNS',
#  5: '4kL2OPLMiNMXhojqQSNkUQ',
#  6: '7tz4b7x6DwHILd1J9qj1vv',
#  7: '2qc41rNTtdLK0tV3mJn2Pm',
#  8: '4iPR84F8j5agZmhHwUdlPK',
#  9: '5yjbUO1Jocui7RKE30zfLT',
#  10: '470SGea4tIbGLTpKcYJfLx',
#  11: '7kDENNLAOgnizz0fgUB6PX',
#  12: '39RGo9NOqiCfbV8epXxFTj',
#  13: '6rxxu32JCGDpKKMPHxnSJp',
#  14: '2k7En28V8aLSsxAxE4nQdF',
#  15: '7lkaHYkz51sDosEghtLxjp',
#  16: '0YIhVMmaboWI25NVbZRkmo',
#  17: '1DXylZlWbVvlckNqwvjTEt',
#  18: '7GJMYx9DymhkSu7T75jXur',
#  19: '1APhKAeROy02DedkHnbrXb',
#  20: '5ndkK3dpZLKtBklKjxNQwT',
#  21: '2PQ9UX4kWDE3mf2fYGRzqF',
#  22: '2uTWduJySVvAw3B3KOJYxT',
#  23: '5aBxFPaaGk9204ssHUvXWN',
#  24: '5sQJzc7ZGwC4olbhp2kqqX',
#  25: '35umDvKBwo2nG53FZTAVui',
#  26: '1wUmdemiR9Dxw8A2el365A',
#  27: '6nxwdNlg4g7FrLZZB43n5v',
#  28: '10exVja0key0uqUkk6LJRT',
#  29: '5ikCQkCt3TiuYYiLLffYL8',
#  30: '046RRGSoYRQ7qIKliJJSNS',
#  31: '7obdmuirClkgU94pcUy05m',
#  32: '09b5OcuIELTdD7FfzQzcdB',
#  33: '58F5GqfOMje69JMa2LIHD6',
#  34: '6QAd9ZxH3ptahZeWoqKks4',
#  35: '3xU0xHtoERRI2puwRtswLb',
#  36: '2mAYpnSe3g2Y22JcZ2ddku',
#  37: '2yS8NRKo6SMDqCERBV9pSd',
#  38: '0WhGV9lzljq2QKJ8ipw6jx',
#  39: '6tgChgEXkgpoJqmmoFkH44',
#  40: '5wB608tPwPakD0LQunieYt',
#  41: '7efkoQb7dW8884GCnykYKW',
#  42: '5gVgcz9X3QcrcrrDXR56NP',
#  43: '77C3owGTFPmigDDIpQLoiF',
#  44: '1OpyZDaOsvR1SAYU4RXB5y',
#  45: '4ePunOqQbOYoQwd1298g3Z',
#  46: '09UQUOICiqSgc3C8TRhTEh',
#  47: '4lfIttJSYSVBa9L2fLfVfL',
#  48: '5aluWpnmEPLnzbQs691RJM',
#  49: '05eY3BZrosgFI2WMWpRoUs',
#  50: '23unNnCoFrh752EAlQnKpI',
#  51: '1EKC4ei6nrFO0wnSAPtx28',
#  52: '57JHGzF8HzrVyIPS2QQxHC',
#  53: '2VAHdNi9v1ae2FVJmVNKU7',
#  54: '3Qp4Hew1h6BC9YSCNkuYoy',
#  55: '1mAZuRxncE9DLiAghJ4ieu',
#  56: '440MEFxEmF9othCXbz3Y6a',
#  57: '1W8TbFzNS15VwsempfY12H',
#  58: '3VBpsrUi2vV7Uj87ONHu7Z',
#  59: '7o95ZoZt5ZYn31e9z1Hc0a',
#  60: '2KrWkSgWNCMitAQXNeoDEB',
#  61: '3ZvmmlF8EMEpnnK90jfuJv',
#  62: '4ofNP2fRtAwFL7MINCr6oD',
#  63: '1oxVf6OeX1x5R9VxuHZmFG',
#  64: '5nHR37FDSU4I0QQta0AZ1C',
#  65: '7y9fjudnPW7IIhom2ZES3N',
#  66: '3bnPBquC93vbHmamojAf59',
#  67: '5QATXPPyP5f3UWtwTc15Y9',
#  68: '2ajVJyxI4sHmTMtTA3ENko',
#  69: '72PnPUc1qv9UjRPaGVZ1jq',
#  70: '5zExRf0VQCl3GO4Jrj8r0s',
#  71: '1UOuQSSPhpE3vK36X2VeEr',
#  72: '3C8PdQGQy4L36PHv4m3sgs',
#  73: '1fvjrL59qNJVJKNQB8RUg3',
#  74: '0qJxsH9kWhslWau4Ork4Zm',
#  75: '4tWFXbJnjC9lM3UzmOpUiR',
#  76: '2BVUhHYQGZDr1YOQuySRuZ',
#  77: '0iGHo9o0cCImrhjkhi9GZY',
#  78: '0ShV0veaBj1NvWRORhuwlI',
#  79: '0h1JqR0KD88ru6f5yUd7Lh',
#  80: '57ebZKL4lpVlngdaBDuQYG',
#  81: '1bZNv4q3OxYq7mmnLha7Tu',
#  82: '0hG95VUGURuOHoxgts6Br3',
#  83: '7caMdiwqwg1WefL7Jjm23M',
#  84: '43wr0vb9IulqfWiit5qXkN',
#  85: '2j7yGPnVrdIHjHwtyLPJ2z',
#  86: '3Yu1KWrCZ0X79c0BhryYPk',
#  87: '3vENFkiF5PZRluBBtQiwcG',
#  88: '2Wrq8GQOVU5fxs791ypz0W',
#  89: '5hE6NCoobhyEu6TRSbjOJY',
#  90: '4iy2RFU8gIpXF5yaK0l8ZT',
#  91: '7CEDwayfKXvOBta3f6Av2q',
#  92: '33qje7AT4RtLwrCJJNyDFB',
#  93: '5tXNu1Z66uFlhcDSdRLP6i',
#  94: '7tfS18oUEffScrxryTgwyC',
#  95: '0fauHpmSHwodVYIjTqOGHz',
#  96: '3OaTTEwyGvEldLPJQv9pMX',
#  97: '0DQJBF0SWLQ3wo5lH6bdnN',
#  98: '31mmx1u3AEpNqrwdnQR3Xw',
#  99: '2kJWN5tegKl6eHYFSlXh4d',
#  100: '1chh3vtmlyt0mHAdY45Gik',
#  101: '1QwvlTkLsKbaB3JT1AV245',
#  102: '2QYxWgXygoXPlh0b2ruP4O',
#  103: '63daU3zd0ubMpG5sgOorgC',
#  104: '79Pn5ZJIMo3zUwyooez5xo',
#  105: '11CcMcrB2vnBQrUdPSee6B',
#  106: '0KMDdRB5GG1SPwK4F9kyEO',
#  107: '3sc7iUG1Wwpwx7bHeZolgx',
#  108: '7ctAOUlIAs7yuMODWE2Fyz',
#  109: '48AdQvqITMzl0bXxHKvGMP',
#  110: '5zInXkhCwoT9HGWgeKjKS6',
#  111: '5yzwLYOqUujIbHQPvdmgbc',
#  112: '7oEkUINVIj1Nr3Wnj8tzqr',
#  113: '760CoXJ9eFnz0i7nrdFJer',
#  114: '0p1LdP1XicX0UA5GNA2DWc',
#  115: '6U3U5okTlXhIxnpbSAo0BJ',
#  116: '36Fw8K3uH9kPWEkZilzk86',
#  117: '4b3YHpER4myVsne2QK3kXe',
#  118: '7JrMDzLZQ25BJwc4tD8jl8',
#  119: '7JMJW9JldZD548pgVkZNIc',
#  120: '42Rm3uPICrqZINjvxC2grb',
#  121: '0o0FTdXEMyuhqRqG7jUAmK',
#  122: '1XJ0wxnZRAVLThg9UjaBIk',
#  123: '2lP1T5oI2BjkLq9axMhG2o',
#  124: '5TrH0BhpRgs2gkOb992bGC',
#  125: '0IrpRvq73EsMytiKmGFmUB',
#  126: '4NJhFmfw43RLBLjQvxDuRS',
#  127: '2sZHeIbU96txBewcnCJLj7',
#  128: '6uRJnvQ3f8whVnmeoecv5Z',
#  129: '5zCaQxjl110XTrm4LQ1CxY',
#  130: '3Rsr4Z96O6U3lToOiV3zBh',
#  131: '2m5sfYbpKKft4tjVfm9IH3',
#  132: '3RRtPbx5y1ZkaGNNwuDY1P',
#  133: '3JmNi1OPqbrRQfNXlPDsqf',
#  134: '6VKh8iOViFBI7R8Bb9AilZ',
#  135: '421vyBBkhgRAOz4cYPvrZJ',
#  136: '2sUT67owclvKi84Ks1P28g',
#  137: '67Zm35qXdPzYfl1c3M0toJ',
#  138: '1RPZu5nxPrakSD5NumbgSn',
#  139: '4I6LjrgKVERp2HF7y5LbkF',
#  140: '49q3PS0SzgbyvWDwZj7qg5',
#  141: '0c0KqfLEQzdrsKZ7of4BpE',
#  142: '3JVOgZYB3yTpWO9Gpn25tL',
#  143: '07OlYQqSHDpM4dVTIm9J6x',
#  144: '0LpwbxbT8dPiqUnul4ngzu',
#  145: '2t89ulOkNsBOot3ml1OqMu',
#  146: '1KEUVZo7CMTSJoM8doulOT',
#  147: '0MBIKH9DjtBkv8O3nS6szj',
#  148: '3UORxcctdWi6drku1qOrol',
#  149: '2TWKl87Jnmd5MApKEpVCxA',
#  150: '6Yps1naRzZKXCNu1yeVFhR',
#  151: '6iqVP49AYVdPNh42u1E6aW',
#  152: '3rxeQlsv0Sc2nyYaZ5W71T',
#  153: '7rFozxRXGgsNBu4Mh14kBr',
#  154: '0VUslbZxY37h7sWbD8gNDU',
#  155: '55bqpWJMazkqj8A3iziuuF',
#  156: '797yYXSM6wVPRRf3DPpE2s',
#  157: '0cozVDzCEFprS9jh7WbJPJ',
#  158: '2XDm5DwTFhp9OlMXfrPfMn',
#  159: '6zl5IXVgj1nG1fqjUh68xe',
#  160: '11m3JrB2fXeM5rR5yxhKGF',
#  161: '2G7QgTep5IsJHGHm1hXygD',
#  162: '37P7yznrsIGSfuGOzmmt26',
#  163: '6FcVd3KlRxozcLl19FMXu9',
#  164: '11wRdbnoYqRddKBrpHt4Ue',
#  165: '1uVlxzx7r6LBQsY4yqyxSa',
#  166: '3RTzAwFprBqiskp550eSJX',
#  167: '0NHSh9S0VQiFfsEFbvhRXN',
#  168: '1kDGbuxWknIKx4FlgWxiSp',
#  169: '6tqRiiqhyYd6O1TjLcVfXm',
#  170: '07XSN3sPlIlB2L2XNcTwJw',
#  171: '6mfghV4I1CD17FOhDKq7cJ',
#  172: '2qBuSecbkEALQYs1MTZAF5',
#  173: '5V8FS5skZ8uOBQCy3yYgri',
#  174: '4VvgircjTNslqbdDYFJMSp',
#  175: '6srW96PTxrzfiBzggQwkjw',
#  176: '3aOMer5Ggs3szbFvvhgZRr',
#  177: '0alRw2BasYQZdFSJLfLbIY',
#  178: '4rZzc9UpbfzSCOwn6HSNay',
#  179: '1LZEQNv7sE11VDY3SdxQeN',
#  180: '5UDSYxxqcF7prMrO2opRhu',
#  181: '5UK3wj86cVRSZHrteL8Lbt',
#  182: '4nnZcSw4lGTxiq3AvYt8Dd',
#  183: '5WcGRaGsl0b9sul7jVdDgc',
#  184: '0KESnvF7Uqtoiin8GjanBB',
#  185: '2fGa9song5Gee8UEGf6W7I',
#  186: '4tpUmLEVLCGFr93o8hFFIB',
#  187: '30kWYxbBRdP7eUcvQuKwTC',
#  188: '70I9vE7YTwKmelfEplXc5r',
#  189: '7xDONBHUmOSBJ6i1SNgq55',
#  190: '2x9SpqnPi8rlE9pjHBwmSC',
#  191: '3ihmiCsHK3zqlZRIZRubev',
#  192: '3TarSQLteG4x5prong6iPz',
#  193: '6peZxkD8S0tTA2dE7p4IVP',
#  194: '6AnjHMqEAps8VJdHU8RykH',
#  195: '67SfQDU6LYw5qwLwGNsNfV',
#  196: '5xMtVcziLHpIwD9iNWPOM6',
#  197: '3uSVvh3bPDq5XMTHElgfC2',
#  198: '1fCy5EOqmRZCyplqDxdUxf',
#  199: '4tQ2BM0YqEYWvVFFGetFU4',
#  200: '1qvlvLGRANOs1WWtGZ6955',
#  201: '5brXh52RmbO2jjVoMwU3bn',
#  202: '6xgUHoQfcHv3MuB9I9z6RO',
#  203: '32PIgjLACKCEXw4WQJqwax',
#  204: '62BcWP4fzR8axESibNQEhs',
#  205: '0U06WlIl1leJMEHBf7WAwR',
#  206: '61MH29rMIyOfuK7KXQznzX',
#  207: '4wlPkvHKZzP2K8wtBzFRyY',
#  208: '2N5BJEXSPup1i4j2xiGZFP',
#  209: '0yBJEU020Gc6ihKc6IBb3b',
#  210: '21ltygJ3rGHmnqaUzqnsku',
#  211: '4dyGMrZuFcRHXwlsqEEuxj',
#  212: '5TWpCLIhvGlbJmLK1zNpiL',
#  213: '5TI3VCZEcgl1RvLegC4j6c',
#  214: '2ogvMdK4A2988MdWSgRRu8',
#  215: '5sNOPqb16QDnvdyyit12c4',
#  216: '4WLGcWrkSExCqILxDk7ol6',
#  217: '6Ot9O7VY8GvclUApiA3ili',
#  218: '0vCGPbugjEi38T41ZHny1o',
#  219: '5QITgPkiJJLdiqmjK9l7DB',
#  220: '6WBf0WXqyBkCCYAEPUeDxn',
#  221: '020YMlk8jpd2AKUi5B0OK1',
#  222: '2wOqMjp9TyABvtHdOSOTUS',
#  223: '37L0Uo5R9LbpeCQDtlAgtI',
#  224: '6Kvpu1Xs687rTFj4qlGg4h',
#  225: '5WvEHnWRNfz9AOLYclfsLM',
#  226: '1jG1ZA7JbczzWiRdTPOqtw',
#  227: '2DBRjviRrKVLYVECPklDdk',
#  228: '4PoAqzGXLjpuYMmTRv24q6',
#  229: '39wrfK41IeM0MnyUb7w3X3',
#  230: '4opTS86dN9uO313J9CE8xg',
#  231: '06bDwgCHeMAwhgI8il4Y5k',
#  232: '3KNZ9AOjBajjmr6ZR2VGfl',
#  233: '0LeULHvi1977JIDXKWqjEW',
#  234: '1XYSXyGl3WXrHN7EPBQ1fc',
#  235: '4x2kecgGRpDooou3CIYnlr',
#  236: '1fkIW88TYRoOZE6VLIfSef',
#  237: '3amXI07XbX3gDkfrqMsLa9',
#  238: '6E7hjfR2Qy6392SnUqCnzr',
#  239: '3ATHjHGh80R6umDswkUf8v',
#  240: '2VZNmg4vCnew4Pavo8zDdW',
#  241: '1z9u3vLr7gw6IBS8CP8c2X',
#  242: '0WXSfWdvqdhG76X1icKUVy',
#  243: '3RNrq3jvMZxD9ZyoOZbQOD',
#  244: '3V1h3kAdiVDBiwlY2i6dJz',
#  245: '2rJ0sNqZbZn7NCKrdTDD4p',
#  246: '5zoSNU9VQp8qDCUkNkSdmH',
#  247: '5b4d1sad2FNXIOYef3vTDg',
#  248: '01D5XnAKpuAbd9PrYSRCuR',
#  249: '2C3gpQ0UMPjrOQ4FYdylRS',
#  250: '7x83XhcMbOTl1UdYsPTuZM',
#  251: '5zZpD0w7JdJ56hd9rjGyiu',
#  252: '4jXfFzeP66Zy67HM2mvIIF',
#  253: '27mD3Omv4wLk7SlQ4m0CJZ',
#  254: '5MbpiwUeY064EvDIg3sOEh',
#  255: '0H1edn1doFZiHiu2INB2CT',
#  256: '1BxqJ6pOCi8mkSjCbFYjpW',
#  257: '0RBuJpjFEGVDZ7CWq3UcdQ',
#  258: '26GHRG8x1F4AzbCKzUaIbw',
#  259: '4j4NbPKY5EnsEUhdNICINb',
#  260: '7fccTP0QbMl7JIt7WgXim8',
#  261: '6WH1V41LwGDGmlPUhSZLHO',
#  262: '09Djw8hGiJ1YHhVfm2thYW',
#  263: '0DDFk56QBhetDQ1wwNf8oG',
#  264: '31klUqSemCAL25sHeFDTFB',
#  265: '3IISF9rnh262yHTqtzf6fw',
#  266: '4DUQBYAyOTZotSEdKhaf6c',
#  267: '2gRgzV2ooQwweEr4s7lwsg',
#  268: '6sBw8Lm18Aj4Zd4dVzM9WU',
#  269: '4dTr0gD3dQD5dOzyaqdSyk',
#  270: '7bhMBjjQhgPX0q9S4Ajncn',
#  271: '4OA2tkA9YYUK0KpiuZ1JUh',
#  272: '0qmFUEQDtbM3e4C1j65nhY',
#  273: '3LHjL4OtwlsXVSenIMlMOm',
#  274: '2GfRO9o3pZfxP0fQ9oy3zt',
#  275: '1SPQDYH2XaazozBGR3wo9B',
#  276: '0qU8UdzIf1I2ZxyI5OHdut',
#  277: '2Eo4VORMdwb15W8WZh3vl6',
#  278: '6c0f3PFo2d6ZYxjvvFb2p4',
#  279: '3ELktghnE5zeabnHdNycyh',
#  280: '4q1DYHDlHRRxgL0B8wGGJt',
#  281: '0fDF0jjmdouCIeWhNnblwV',
#  282: '2e53aHBQdCMKWqHDuyJsjC',
#  283: '1vB5909auE9YUaTjQ7ZkTj',
#  284: '4xXCRXOfQKQ2gjWxNhNzYW',
#  285: '4JNfz6aO9ZFz0gp5GY88am',
#  286: '7sOR7gk6XUlGnxj3p9F54k',
#  287: '10KNwWrrelu4GEV7QjTCd5',
#  288: '62oFBAu4tO3Nw4TxF9o8R4',
#  289: '1P6U1dCeHxPui5pIrGmndZ',
#  290: '11lfQgLbVZRnR7tbtAnzhk',
#  291: '5yzE49FicYiSxN61oaxkNn',
#  292: '4J1sCunO2opMaVqGbtSnit',
#  293: '5vqNgqz0P61Iipwn7NjT5P',
#  294: '4XbcXL8SaLFZ30wfRM5tbB',
#  295: '03G0pJHLHj7FRuCV5OYzpv',
#  296: '1NyswKLrbbWby73lOfJRZH',
#  297: '6OITsYO1BqjC0VIF6yGFOc',
#  298: '0UACE2nWl5uUyJRo1kIYQO',
#  299: '2dqIIRLiA8etA7YCkIRvob',
#  300: '1mgMUiCLotueW9uU9ZZjk3',
#  301: '5L1n6wVJMxBw6sZbxD0XAU',
#  302: '0UQ0RWEEfYZYDzbACuhIhM',
#  303: '2rNCZVyZwtSaTI1HGj8LFD',
#  304: '3BVkDHWRvLJEyKdvhLbjsq',
#  305: '2jYQN7gUHmIyLsIuLUbq9M',
#  306: '203FukGHCpUXcRMpMvPGkj',
#  307: '1xE3snzm12GBK259IqEFlY',
#  308: '0o1wK6uAmkrixovsE80lMR',
#  309: '1dyZDfHcTtUJjx0DFBcOvc',
#  310: '751d4soU7iC3TfGl8y1EyU',
#  311: '4QuVWcl0F9IqBgNMmmfJg5',
#  312: '4uIoERKmmKxNsGXvVoSodB',
#  313: '16dRLjwqzEfPWoBK7wZYk2',
#  314: '5tvXbbkel50ydEVPHb9b6V',
#  315: '4iZpg2fbTmpRcjk4qv5nK1',
#  316: '5qEhKFhIXtSGi9Gw449LKX',
#  317: '6YB9sqHoLlgUIRnjgSSgXT',
#  318: '43DHa7Q1IhECAE5YtN3jHQ',
#  319: '4HP9KltldfmkH2M2pQozzN',
#  320: '4i5BO8J8LCbzc1on7npUK5',
#  321: '1ZHio9RIhXSROw2pqxiZ91',
#  322: '37KB5e6cGsN1AQAB9Omm1U',
#  323: '2FmzVitXZjIkFolH8HXd4j',
#  324: '4XvaV0jFnwEthusiVdEBHK',
#  325: '0Wn8CfFuAEhYZb9QT2Xekj',
#  326: '7yPPzu5UdAK7yagQqjEZQm',
#  327: '3d2xlrGC9JGD7ycsf0e8mF',
#  328: '2hzruNUjAWRn1Cd38jIVNN',
#  329: '2aaLAng2L2aWD2FClzwiep',
#  330: '2mSiPzmzBCGS7p6tEuRuTd',
#  331: '4hSGrfIm5xRloHXESKxrFd',
#  332: '7pq7EnlN1IHSyffRTklSqP',
#  333: '5mfdtMy6vJUShmdyCuJhox',
#  334: '0VbT1p7WeiB0q6BSuBIImJ',
#  335: '1xQJFztRscXND4aMJ1Ic37',
#  336: '401lvXkwSUvbmZdgN3Tqt7',
#  337: '66nOkPJTFgK25NMmojG04V',
#  338: '0m04NLVsIfjqZMBfw7vTf4',
#  339: '6QFzNRixcYEwl0tbWjPHtb',
#  340: '3IViqpVqy9kaQHYcUKP4el',
#  341: '6ZA5hOgXrwewHpoHJL57gW',
#  342: '5X0N2k3qMnI8kSrGJT3kfT',
#  343: '6E3i14HLHEfLnlJjKXoKxT',
#  344: '7E3BRXV9ZbCt5lQTCXMTia',
#  345: '4k2R7rFptalNPkyGEq2s9G',
#  346: '6IzjY421I2xp5UR4dkMDsU',
#  347: '5fyHpJg1xW8OZqPyzmQv2C',
#  348: '51dnWmy6IGp9FDFUV1Yfst',
#  349: '0DR4z5jMA1eqx0CmHBUpkr',
#  350: '3pkpeMHQ4KBgEuWDaTvzcp',
#  351: '4TnftWQx6fF7k4Nviu7Nn6',
#  352: '55tLEUlrzGNtACuMVJZHNf',
#  353: '1MDw0zSUU0XtI9D5JgEZH5',
#  354: '3gUcKxYK532hXeuze5uXDg',
#  355: '7IOD2qSIHhToedGtCHQj9Y',
#  356: '5Y1zc5BJKJG3Th8fxtw4dn',
#  357: '2ODTjg0iTHX1QxBeRNI6nT',
#  358: '3A6RBkFY3kND3Z5kXM3Cz3',
#  359: '2z6JjrrJKNLilqlx8mlxcc',
#  360: '5os0Ltvz8Q8BvXOPOd1frx',
#  361: '2MlEIMqlnk7DFA1WJY0Iva',
#  362: '3ohcHMuUq1717s8AH17hfT',
#  363: '60GtR6PIcDY1pikPgKHNk9',
#  364: '4DWnSG0RYPAds8EIKY26q3',
#  365: '7d7q5Y1p2QWS4QRAhTQR5E',
#  366: '70BYFdaZbEKbeauJ670ysI',
#  367: '6QWhsOtNSHnGk1LO2rMj63',
#  368: '4ZyVcJrlUqF34lHnBwn3mK',
#  369: '3cMB6N9eibNR7g8sD3OL8J',
#  370: '7u425UcXjun8fogOPhcxec',
#  371: '2CLWZP9ZwueC8Yx9ORbxlW',
#  372: '79S80ZWgVhIPMCHuvl6SkA',
#  373: '3Y10boYzeuFCJ4Qgp53w6o',
#  374: '5IIMXutSfFKPRKkabg57gR',
#  375: '6O2zJ0tId7g07yzHtX0yap',
#  376: '22JuR9OeENcP54XN5TlNWS',
#  377: '1SAugjIcuwNPKS4urSB7A6',
#  378: '4LlDtNr8qFwhrT8eL2wzH4',
#  379: '1hCqIsNERHGFKDQ754m47q',
#  380: '0D7AJFMxwfUS1kgjBQJ2io',
#  381: '4JDLFCiz6ccxa29oA4E0R6',
#  382: '5n5iBDC9dOljWGwj7BrdZt',
#  383: '3SJIvORDl2B7lBiEtiUU7g',
#  384: '28V657x2IVJnSW3Srw6Ubd',
#  385: '3pGgFAbmQ22e2LWjOtv5jH',
#  386: '2eMZsuJlUdllW1yrtGWNDA',
#  387: '4vV17Ak4JHEHXRW5d88YCP',
#  388: '4fFGgkEViZ9fZVqpS2PL2U',
#  389: '1xszBQ8Rx1QtaQJHi0Lcfa',
#  390: '41OU9MTrW3kmHZdZ6jNMzE',
#  391: '0ax2jaKxNf0AWnWaJnovy8',
#  392: '3BlpPaAKfZvDCgy9Rvzb9a',
#  393: '36pCa1JHc6hlGbfEmLzJQc',
#  394: '5L6lO4X5v3GJpTkBg1BdW2',
#  395: '2EO56JK4txid1Pss9GVbOL',
#  396: '3JXUq4yxvtP3Qut0yjoNQm',
#  397: '3jdODvx7rIdq0UGU7BOVR3',
#  398: '4OzJnEy8ZSFGgTfJRlszdL',
#  399: '1XIIxzmo6BNRR4QkImSdsX',
#  400: '7bHm3B3jJju0q9FUdOgp3b',
#  401: '4admDxmnri5Zco0xYrJ0ji',
#  402: '6GGVr7WgIWhsnJNdGyPklP',
#  403: '3mvkWMe6swnknwscwvGCHO',
#  404: '5MCl6mca6ZixPR36dHH9Sd',
#  405: '1Eqmku5RGosz51zTCZFgDi',
#  406: '0b4SurbppI0Uhv40rlkCj0',
#  407: '6Dn4zuoJoLzVic5rgUseWq',
#  408: '6NgdG349NLTViR0NJqGGRV',
#  409: '69lxxQvsfAIoQbB20bEPFC',
#  410: '1pzNRIDRT064HEdW1nG59c',
#  411: '2U2lFXyeo2savjZgG9JTyH',
#  412: '06EfEcjc0vdvI6VNL0soIO',
#  413: '4RuwsXTtshHIbbhgi7nAxY',
#  414: '16rfiZrUbpoIJKqvJjbOk1',
#  415: '6Fxw93ezsZRlLdYWxyHqO0',
#  416: '33NmjekkNspaG6tHcCTEW4',
#  417: '5I403ygmKYGRhRoirobj7O',
#  418: '4iMxCzxSN6HAl9JPqmTbRT',
#  419: '4k84JZ3ge2ZeFyKCThIiBt',
#  420: '2YjrANDR9gCMbNjwI5OWsG',
#  421: '6fn8iEKAKmUOhYpmLlSFOh',
#  422: '53IfD3QieElrbwdMkNxX6G',
#  423: '2l4vGfFV7e46yO8lxfxR76',
#  424: '0QjKu8W5tafMCDKKw3xHYT',
#  425: '2FjkZT851ez950cyPjeYid',
#  426: '34Dog4Ylyg3eUFJF5Rk7Hc',
#  427: '7GFtsLGIM7wRmfGqrdAfkG',
#  428: '0ZptpOIyZ9tKh94WgwOuZT',
#  429: '4ijGLY4dzlurDh7jqH3tW7',
#  430: '1WHFu22zN1C6F11Z1rt12K',
#  431: '0RHOoF3Gk8xeWJyozvvvle',
#  432: '76hd0I6Lh4D1G4uxmC1p9s',
#  433: '0UGvbhPBJGBi71wtIk3wuo',
#  434: '6ncJaot7xP64UeIQlmPIel',
#  435: '3j8Vtsosedh2OfhYZ381pC',
#  436: '05RZIdfz59ZW2FvFuwnmNK',
#  437: '7rctdm3Mx6mTUuoQukPzHM',
#  438: '74aT58mmwQWq4qUxTE0SDr',
#  439: '3Ju3bW8OaeUmfQKqMtATKr',
#  440: '0a1gHP0HAqALbEyxaD5Ngn',
#  441: '6lGCmXtqSxze8o2KEfYD6D',
#  442: '1yWjNh9SRE7C59A3LDIwVW',
#  443: '4kFnO9EhFN74EK1a2UH5ZW',
#  444: '5z1vzTURV3bwwXqxkjy47W',
#  445: '4bFfSfCBYpFh37ziXCSqUs',
#  446: '6C2OWSuRcg7cZL4fsAJ3No',
#  447: '0t1uzfQspxLvAifZLdmFe2',
#  448: '4o6gZFD9CkUCVzYqrDR3wV',
#  449: '2DntubHirEICSdXa23WNpV',
#  450: '1GKYNY4rIPnOuTfC0J1IWw',
#  451: '2Np3tBLhkFCcJPun4KhrDQ',
#  452: '6dQgkiJm1fRkcqKOvPzysr',
#  453: '1aVONoJ0EM97BB26etc1vo',
#  454: '2WgYGKKKnmn7t11fcHZnt7',
#  455: '7CXgiYtZiPnwxHM8ad4hNZ',
#  456: '0RoKLhz5hsmsDak6hwkCSa',
#  457: '6ykfXAed2KOLOMI3R0TZdz',
#  458: '19CDHEKuNmsiY9VFfdFfgB',
#  459: '0GCJ4kJKmHuLJw6goEKAP2',
#  460: '3AdesIUtjOqgbauvNgSP7B',
#  461: '7IbO8NvxclKsk7WTOZ42bv',
#  462: '1HBAG7fNtFM5CcTW9G8e5w',
#  463: '6DmkjshMbzt0GiEw0IBqRb',
#  464: '0zJPYcXL0EqOvS6LLdV3B7',
#  465: '57fbnHozNJMl16yNzt4agV',
#  466: '6yrtCy4XJHXM6tczo4RlTs',
#  467: '3Ij56hbjOTHq8RgutQwfxC',
#  468: '6kudMw2A0xOBJHpW8VNaDA',
#  469: '53AE5CRxMddOKRxKE4oGKZ',
#  470: '1Tsag5J854qxeOo2apszug',
#  471: '0QT3ZWrppXpw96ZbC2LcSl',
#  472: '4LMsUGCTzMsLYcL90zb8sF',
#  473: '73ITRDqlSE4huQlrKuqrBU',
#  474: '6ioaRkg9SnP8mC2NP7Z2rB',
#  475: '13xEB2Ahsm3Gl6rFLKFqbA',
#  476: '6jW6lFOKSTQyeX2sogdQ6k',
#  477: '7butkj3jPD2YeHBuWFp19k',
#  478: '5S76x1RQk1FgHwX3y4giOO',
#  479: '0XHiH53dHrvbwfjYM7en7I',
#  480: '7fh7bwX9qV60tLxxsp9bTe',
#  481: '6hkch2KhRl0tywpeVK5xR5',
#  482: '5wRMAVogaNWmArSGRcAMYl',
#  483: '17Mb968quDHpjCkIyq30QV',
#  484: '3OxsMm9KHw2FRJLGHtILl5',
#  485: '26PxWbEO1ZQ5Q4LLBmcbyH',
#  486: '58XGUNsRNu3cVOIOYk5chx',
#  487: '1IpSmgcN9F3KNa7j9JtAE4',
#  488: '56qas0WZSMz09AhkPklAQk',
#  489: '1d0FteV32q1ue4jDMwIMH4',
#  490: '4gcuCFzrnm2oDNMINc6IVF',
#  491: '16aBntAT4cDQ7OKBMtpwDB',
#  492: '17vCFclNbTzsDfPgsaWaQO',
#  493: '0iUdFhwiXjGQWAt9yXPP1T',
#  494: '6b58ZzXRHPakxMhPx7xHAx',
#  495: '2tbxcCCM7A71cmkzuB8lyH',
#  496: '5RXVxV5eWWhzou4tkjawRy',
#  497: '7aetQGX0sd3swXqUIWurrE',
#  498: '1mG23iQeR29Ojhq89D5gbh',
#  499: '048FBwXjFYBWxSggPDipic',
#  500: '2BhI00WWkW80lJ9SHDf08o',
#  501: '4hxDvVq5t8ebPYPdBl1F9f',
#  502: '2UEnhov0KDPYU2dmGUjfcn',
#  503: '60fywHiwIsvidRZIp5th04',
#  504: '634K1Y2zhBHexel2Ma4xsC',
#  505: '2FrQM3hYDld2cLxy5vXuU7',
#  506: '2gNK2HAaLVz5DZoD2moDQj',
#  507: '3loflELg7MzgrOyNqERolN',
#  508: '0nDKBpRAcd4Uhqho6Svcs6',
#  509: '4ITkzAQWPILwWpEWJxHB9g',
#  510: '1J65MRryoT7CWCesOe3nBb',
#  511: '11mqrDSFRRz8g0Wb3syJj5',
#  512: '39wff4xdW1Xg88XzoTvySv',
#  513: '1Z2XrFvat8f47ZaRfjTgZL',
#  514: '3g34PW5oNmDBxMVUTzx2XK',
#  515: '2hcsKca6hCfFMwwdbFvenJ',
#  516: '0AD4odMWVQ2wUSlgxOB5Rl',
#  517: '79WQXZhxJmJ3XoY9AklvBL',
#  518: '1xhTkIWAZxPeZpJWbjClqL',
#  519: '5ApmkOetrtFUZCEQJqjejK',
#  520: '6UIF3ueMqdcTeR3VNUyKlj',
#  521: '6WTEAIr2PTM4nCRqtYRXNg',
#  522: '6T4sT6axXOoIXP4cpaQtNk',
#  523: '6PQIV8IsLTo2Iz3Ms16ArL',
#  524: '2qBg3GRK1U9XCkJ9JabBt3',
#  525: '7dCTyOTIdbIvCxox9ocZlv',
#  526: '5mxTTphe846pd83WsQmfp7',
#  527: '66znpbIBZzFtvn4iqGh2Lp',
#  528: '6wm32IMzCXPVSQyhHq4WVL',
#  529: '5Wh3G01Xfxn2zzEZNpuYHH',
#  530: '6X3QjCYg5HcTwO5FPVQj0J',
#  531: '6ZjkbKhBbgGHxsI2InF32u',
#  532: '2Ag3w3cSdRHgzPNi60WABE',
#  533: '5A4ebXQf38xWIq0xSWLhsS',
#  534: '6i0KVTOvm96T55mbp742ks',
#  535: '6O1LPaUpomBXV0RSosyvdn',
#  536: '2Icsf5D1lAs2EFx6kggg5D',
#  537: '4RjJxd5GobUt0FzT0wdTyG',
#  538: '4WoKI3ZPs544x2glFOJRyg',
#  539: '7MbSdIkdgkwmVxObpCg87e',
#  540: '3xgj17ZsWxxU86S4qlWvOi',
#  541: '3Y2UMfxP15qisezhYgjTKN',
#  542: '0qt6QSruHshcWT9QOzyfZp',
#  543: '267VY6GX5LyU5c9M85ECZQ',
#  544: '4AoyW1nGxPPHJNb04AHeS0',
#  545: '0ODUQ3W9ljLNLJELvO5ysk',
#  546: '0mKi9K7XoFGTNfOhwlxr6Y',
#  547: '08RxfNkJpjJ4dJb4xASWzj',
#  548: '3sYr49vFJ6BPZnV5Ky1PLH',
#  549: '17Eb4wzkEMdGVgHmA2Ui8C',
#  550: '6AwJVvbGDd8jwqstWbZGcA',
#  551: '3TaLdYu9rA6H364ROYMmvF',
#  552: '1pqEADBW7q6GmiKpHYCUGD',
#  553: '3cxdsx3CM35nWocmLQYxXW',
#  554: '7pwjGKaqnfkvS7eQbHaqyH',
#  555: '6EL5GD53kaaVgJCHgdtdLz',
#  556: '7fx2SnWEZWNwiP4iLsyQvq',
#  557: '6stFJpRU2haAAmJjSZEuVW',
#  558: '776kaEvP1Qw3d7vnBHHRJx',
#  559: '5dk0R5am4zMYmG6uyZwfkW',
#  560: '51Blml2LZPmy7TTiAg47vQ',
#  561: '3eyatWaNEmNmkf4klqcNiw',
#  562: '2XJbXqEZAerqrG44oPbBBt',
#  563: '27GfXDC49oR4Rk5DTGnPXp',
#  564: '571Pyg82o4ARKjrEcaBD2r',
#  565: '5XbtWFLdL2sXDUo3oqzn9b',
#  566: '6vN6bIVUA9rT1gCreTIcAM',
#  567: '1Ih0fEQQsy9EeAJbYEeQRa',
#  568: '69lt02nubfNbPdrvH4tJxx',
#  569: '1ejXaEB0Fh6w9Ygg5WrL4K',
#  570: '44jDvLRX5YIUBQ7th8xw6G',
#  571: '1kbDI5eg73ftGzwOf4OKZL',
#  572: '1Wmsh8shHV9kBkT3F9M40U',
#  573: '3rqpBcetrJVphNTRHDv9ht',
#  574: '3gACvSG61fuDRQYBi6izdi',
#  575: '3LE4OOntA2Yq3x1TTuQURx',
#  576: '34E3csCxpXunPGEkOVVX2g',
#  577: '61KJdJU38zrAW4c3PI9C9N',
#  578: '7DCTgrI6aDK3nBRZm5RUKT',
#  579: '4r6mwtaNARbTHv5Nk0FXvj',
#  580: '6FmHMrX0jETx6WNGzyZKRs',
#  581: '2ILC8RBzrhyAE3MPfBe9sQ',
#  582: '22ojy4H4ZVpowC4lRRC8In',
#  583: '15XyOjcwHR1BLzZDpcja9f',
#  584: '0DGqabk3gsZWS8zEdgt1m5',
#  585: '3DmDJOQgrwlq8MxXGLeFvA',
#  586: '2KlDlqEMf0YyYW8rBKUx6W',
#  587: '25iPl8VJFDu38JMFF6uMXI',
#  588: '6OO0PboZcIWUWL7j2IyeoL',
#  589: '70yI3vIoUn1I6vFlbp4iuo',
#  590: '4jDenReylh2CLShdLQ2Hyl',
#  591: '2XTff332rrZaE1rBM47Krp',
#  592: '4BtHqD7zPjbetmJPFto95d',
#  593: '1SLFnlhgHr5lExgdr6YeoL',
#  594: '6NAOD3WFsejGYe83g5IID4',
#  595: '4oawINl9WYHGjlW5a0oK4c',
#  596: '6p9UqvKboiXAMNOZGgPaKp',
#  597: '1pIGo5JsNaVLqnr0yFno4D',
#  598: '4AQrqVz6BYwy29iMxcGtx7',
#  599: '5juOkIIy18sFw9L30syt1Z',
#  600: '0SUxs8Xj1u6jJA8AK9H4G1',
#  601: '5TcSmqbuyYcyn396CFLwPr',
#  602: '7GIppuyFeDbg59Qvll6tCo',
#  603: '2TI7qyDE0QfyOlnbtfDo7L',
#  604: '17TLTIgidZF0ypQJRBpp60',
#  605: '52JDGHEmHKktNs1lN7HCl8',
#  606: '1r2U8cAvK4omurH0XzwX7C',
#  607: '0PUf7ZQsGx7s7en5EVfNNx',
#  608: '2fVE2lvdq8anZj8lKQmRrR',
#  609: '4S2yOnmsWW97dT87yVoaSZ',
#  610: '6w5yeNC8MlJULj8xchc6lE',
#  611: '6KVc8Llznru8n9LVCYe9dz',
#  612: '4RjtLUZNqLtMpRKIOaVokc',
#  613: '5cilSDFcAQcLwh0dNqMhrE',
#  614: '3SNYGr8ltknwLPRNNmgGdy',
#  615: '3BqAAo5E60L15TcFgWI8xH',
#  616: '5JqaR50nAadSYO26G1x97a',
#  617: '01N1aZStXA4yGvkz4vRXtJ',
#  618: '4rC7yC4tin3n8FyRUUA80R',
#  619: '0gQaWddG4xubmT1tY1m8xm',
#  620: '3wury2nd8idV4GecUg5xze',
#  621: '2Ah9OuOj7B57gPD1cbwiaE',
#  622: '6iNVICWoG8BfqoyejEQdpF',
#  623: '0CUpzKPDfIVzYqMn47jiV3',
#  624: '3PkGkJmTotXKubtTksWboK',
#  625: '6I2sSTGn8oSbEEZU3eA66H',
#  626: '65qZn1fOtH6mwNK9CaJ6HM',
#  627: '0IUq1plF3ON4Fboj1bE6kN',
#  628: '1oR9pQhucVTJyi5lH2Y2iT',
#  629: '0DxYes5zk3LMaliyhYdXHN',
#  630: '20OEywfcjqmp5gsE6Nj7FA',
#  631: '1AyWsgtaIgXbzjJlTx2ZDp',
#  632: '5tJ5CFnO4JQmLXaarEyHKt',
#  633: '7jrRQZg4FZq6dwpi3baKcu',
#  634: '716ZwtZBmwROBXcFmCzfdM',
#  635: '5RFp6rGljFShfXltofv1zi',
#  636: '7mQilAy42MqNPqUFqK4Z0o',
#  637: '03KLzHVK6la8dVop1iVI5x',
#  638: '7mAKZuvKKiNRokFE46Sy8l',
#  639: '5YCEHjtKf4jnGjXK8eLPn6',
#  640: '12L0n6FPcTKBtKvWcFEbmP',
#  641: '3BM0EaYmkKWuPmmHFUTQHv',
#  642: '50CspSWbHQ8XLjQVW1nIW5',
#  643: '2O2MRdVmId5VbqJLrNw8fx',
#  644: '5Lrt6m5pv8WYS0FNpkCOg6',
#  645: '3FsTN0noP8dkaeQVgwEgn0',
#  646: '3uPZlzXot1zP430egHclH8',
#  647: '02G0wSA5mAINnHX3nTCaHi',
#  648: '4xkq9Qx4AynPjt8m4OSOBO',
#  649: '1Be36RHAlqJpfUt3tsmUQD',
#  650: '2ErWLckuGFl84nGmg5fwyG',
#  651: '2pbePWVNtbsPWxUgYg7a79',
#  652: '7h8ja4JSORo2sXJPmCXRxa',
#  653: '4OPwFSuypxZLw3ZL0Ei2UZ',
#  654: '5DKuVtlpDH0agZQUFDy8O7',
#  655: '14XLmlJANyh7F0RCOnvM31',
#  656: '5dRk8JyA2Tg9wL0iiTqbVu',
#  657: '0lKpKsvjBKLUeyVIAPHUy1',
#  658: '6nUPC7IP7bPYD55OxAuCOw',
#  659: '5kjb55jtwPnbYXXDvP4x7R',
#  660: '5Rk9nXVSA2RzBdef3aTJPR',
#  661: '2dQdjjxl2kIRzYzLUWh3fG',
#  662: '5EqWm8g2vcGLqOkiHFU86V',
#  663: '4mjVQFIgNetwBWatbQROKq',
#  664: '0cLSrHAGimBuxfOfgyRvPg',
#  665: '6SY0dU66T3GuDJai2D7s6l',
#  666: '0TOxXmVdWh7kRitBUuY4On',
#  667: '42E6wyGuxlqsLx8BFki1Lf',
#  668: '3pICQ7QvYXozuzJjgb6eM5',
#  669: '6Z112eJxKl1E3nAbYZBr7M',
#  670: '6kz53iCdBSqhQCZ21CoLcc',
#  671: '1RgXxY6uzWo9cjYYwwgVGq',
#  672: '0AjnB78SikKKhqYoqFIOXn',
#  673: '339BdzmWBEQvWqxs6lGhUm',
#  674: '1TQtbRQbaXw5CeN3mC0DJH',
#  675: '4en7e0KjSkfa4sfLDhTc3m',
#  676: '43BBY3SaqpXKAEwSR7y53Y',
#  677: '0M6xcJTswOl2qvExCJhiS3',
#  678: '3LqgxOMfONGBf034jekl9H',
#  679: '64Behc9DfudbNaMNab9f0n',
#  680: '4Sld5LOPbAm1QSq9U32fFV',
#  681: '0IVcLMMbm05VIjnzPkGCyp',
#  682: '6vVVP62kbZ44LQ0oZrV5eU',
#  683: '6vPWHPVNpVuTdwRsjX7Sch',
#  684: '2ixb8I8BVdLRywPPklssgM',
#  685: '1Oos40mD8hfvswQWVjkbg5',
#  686: '5CW2x4YosugZJZZCWA0kBI',
#  687: '2tKGISNf0bei0IxfLQGMEt',
#  688: '4OBbOrkD4geIjOLrICN3wO',
#  689: '7CrVv4zLga71gdlMOMfjXL',
#  690: '0ME1RawvWt3qOJnYnxVqeh',
#  691: '1RsidBdQh9dqKrDdVDX7Yq',
#  692: '67C3WSLXod2OCodSPcHRs7',
#  693: '1QsX6patGKqJ31DHnyAKYc',
#  694: '7KGHdp8s54UBCKDCxVNQwj',
#  695: '5f3XEqM6vNrETqlzCMufGK',
#  696: '0iPuLiTIWO8BFGjWxvT74O',
#  697: '6VStmfr3fOFBa6dCg1760y',
#  698: '6FlxhoUGATC40TALMesaFM',
#  699: '6rUsAEYBTCzHDa98JsBwtW',
#  700: '01wau5CL3Z1vfJJWkzBkqg',
#  701: '4wZBiNHbCi2TMXjSP86LJ6',
#  702: '04Iukg2oRw5EqVoHuFkL0i',
#  703: '6JMHws5haIO6V35YNYDnDw',
#  704: '1EbvbxCONeiXZTVIS2Cw0e',
#  705: '0X149njDwV5sDZRWdkNYIP',
#  706: '5ctgKd8fwNFHpT6EIiXHT1',
#  707: '4N8BwYTEC6XqykGvXXlmfv',
#  708: '08AaSBXiJK2hjYzZkC0XSd',
#  709: '5a31Ij1sTxY9LUYVwgBp8m',
#  710: '4DeF1n7pWrs52PhWd2sEyr',
#  711: '6AyERpbxNABmMvKjdhPMAU',
#  712: '2o89XmjinOQxVzE5gn2r8v',
#  713: '5CzTm7YPNW47IWv7qi9Zu1',
#  714: '01aC2ikO4Xgb2LUpf9JfKp',
#  715: '2O6eJUyJKuh1N53GamH6Tw',
#  716: '1lrmYxCJplPJBUZygmooO6',
#  717: '28jD4Qh0ov3Jn2U9ECdUcW',
#  718: '1y4mNomxnoThRF89hM0Unm',
#  719: '1NAWG3AngjBXyKbmPaz92D',
#  720: '7xfaPAzS4dF04LBr2dKXlB',
#  721: '1RCoE2Dq19lePKhPzt9vM5',
#  722: '5RmLUrjJz5bpP8dF4lYdyK',
#  723: '3SP3zwx9ot2sOEf80VJA5A',
#  724: '2CXwRGFTYdcEAI44NT7qDR',
#  725: '6F3N8cG6j8WgLBrvYiNNFk',
#  726: '5iTOaSGMZgJ1U8k6NjmzTx',
#  727: '4EJsm8GVADYCXpKNNrFjtu',
#  728: '1deSNOUsEu3XFsMK59b6gX',
#  729: '43oucnuGRuY0rtiW1ViC8D',
#  730: '6n6FVIstoz4bEZSPYB3YEi',
#  731: '53qbUwdHW5CqjgJZdHVOxi',
#  732: '2E0kgEPDzzNtzXFOUPNCYV',
#  733: '3TaTWEHHUV68OvZxhG2xeB',
#  734: '5B38ZGYpd0msq1LKOyz2r9',
#  735: '3kXHFMJ03L97ZTcOW1cxGo',
#  736: '2xnkhppPrflQ02TWRtIthQ',
#  737: '0o1eC2L6gOIyKwkAtxVAWH',
#  738: '3a0gvZAydt98HKVbGb0V67',
#  739: '34utayk0DUNl1YblAHEAQm',
#  740: '0c3RL3vVEgfxD6VBv7CGak',
#  741: '5b4SvpTqll0LSqJWPpXya5',
#  742: '7JfsqT3StNdmVbK7vM4xgh',
#  743: '7MEg8CCRCKcaiH1ywG5jOo',
#  744: '3PukprT6kwBjkIti5fpUCG',
#  745: '1LB8qB5BPb3MHQrfkvifXU',
#  746: '18absyD7lQaXUDBXnyzU8M',
#  747: '0vn7UBvSQECKJm2817Yf1P',
#  748: '6KrZfPWnNQoZci1kA4QbWE',
#  749: '4fomCZiFUMX73KJ0YQ0V90',
#  750: '1CePElDvaklroVcd4Q8tEF',
#  751: '2HmvtPbOeL9x0BSRyEgQen',
#  752: '7jNvyyfgfDOM4ixD8LHhzW',
#  753: '1A5oymWstOyE3ZFeELbBtA',
#  754: '55BOGnEb0pUuAgbxAwwbKV',
#  755: '2bmHKyjcdyqTMUxVbhZJth',
#  756: '7ACSlU8kTcQIbvpwLWze8E',
#  757: '5GqAhBdaiG5StP2EHhmw8B',
#  758: '1nAFTfHqP2WGCKJDKH5yqx',
#  759: '71MaDLIywcEKpXNGCnUlBe',
#  760: '294lNTPZfdqyzt8qnxmFiL',
#  761: '3VD3oXiELCSHXzR4XXnlaF',
#  762: '2iZuu3RiN40mFVUKkHcDZw',
#  763: '4FC10Nffya2LWWVBfrw0gr',
#  764: '0oBEeN6BCxEgMogzThqrPf',
#  765: '4ze1UwMqtSlhTgnyk8LrW3',
#  766: '5kXK8waG1JeBQ8b5leWNSu',
#  767: '2hxa4ytcni5FUIK8IR27tX',
#  768: '1VQB0XIrSpZj3xR4HQ3yvO',
#  769: '3Eeb1U0VJTDaFpBHV4DmHl',
#  770: '7D5oTJSXSHf51auG0106CQ',
#  771: '5XOmCjTlwPYN3g8BcyJhAj',
#  772: '3ImqpXKKgkH5VydfgX1hd4',
#  773: '0cIx910hgtpgvicBJv3ybq',
#  774: '3CxVGnYMLbY1wm4cxsKSEj',
#  775: '6q6VBUUg2WGshfqLFqUmtl',
#  776: '0UnBsBrom4chs5rnjRBtIK',
#  777: '5RBdF1pJSLF3ugc2Y2PoB8',
#  778: '2tmFn09HiAx3WsimtL93fU',
#  779: '4ZISAmHmQUDCpv8xydqeKG',
#  780: '0dkFacPMrWkrQzjjhcMHb7',
#  781: '4H7QVpyCHkaUeEOpCPzZQk',
#  782: '5bzgA3owkcNXRwyiITCiwe',
#  783: '01Er12nK5rrnHx8usFPJAs',
#  784: '69MEO1AADKg1IZrq2XLzo5',
#  785: '3AQTzCOQXIVgCTcYM9FLpq',
#  786: '67qogtRNI0GjUr8PlaG6Zh',
#  787: '3cMInYqk6yzf37zo8iznoz',
#  788: '54pgkpWVgQYbQXD8bkUP8n',
#  789: '6GSLe8wDhKFqIPqsB1Ricg',
#  790: '4ZcihAoljaPhXPrgLaBJO9',
#  791: '2oyNl6Ds6rY648mcUFhVgT',
#  792: '2P7AfQW941UU324qq2ggZf',
#  793: '6dS9ByVYMgK25UoGA7mm4T',
#  794: '1vHopQ5qWJVDXXPc2VxjUd',
#  795: '3BRjxpDVT56Y2G5dS3xYZS',
#  796: '0CTKq7arHzG8F0ToHBW8qj',
#  797: '2aWjaq32aRQo58dw0w8NM6',
#  798: '0EikLJdrz7f8ocaHztUO0S',
#  799: '6BYwseleN4FiZvX4dFirBj',
#  800: '2a0fbijQhcaj1hOFp5b3id',
#  801: '6WJZgV9PwH02nHQUMUam6g',
#  802: '7oPftvlwr6VrsViSDV7fJY',
#  803: '0PI3pXpUMScjweiw3IbADc',
#  804: '56OMwqr8qaLIRH4ZrvvdXq',
#  805: '0cQuYRSzlItquYxsQKDvVc',
#  806: '3Cf7jFBOVBRDTvFUxGAJgF',
#  807: '1MlFNDlH2naWutA9C0nNVB',
#  808: '04yNJEB7tEAEie8UWjzTAI',
#  809: '0qAmeOULjwn04k6jMMeDyr',
#  810: '3A000QRgQB2uCaOtWkafuS',
#  811: '267SHEPfqnF16IEmwbLhLQ',
#  812: '6fJM13619LsYtyPqHvsf6A',
#  813: '56snND3YyUX2aZQVXwgLeq',
#  814: '2kqR2YJ2tTLW2c9r7jaah9',
#  815: '5A0MH7JfEBEMySevsmauds',
#  816: '27aJr79YUyfK5ZrcFxF5u0',
#  817: '1aTDTChWWyiJH3SEnYrdVp',
#  818: '1hLUGkZvkUxmwCNpPJg9w5',
#  819: '1tY6Z4NEPI3xHhVA8VU9Jl',
#  820: '3plJVWt88EqjvtuB4ZDRV3',
#  821: '3BD60vhHcGClnZ9sTD3k2J',
#  822: '7CwiLiC1S8B69RMPxbDb6S',
#  823: '0Y2Zvpo631ACDnYOllivYM',
#  824: '7J2lZBANizgPNfUzux31PV',
#  825: '4fQbIxjM2vH6YF4OsWlaGT',
#  826: '3SMVDdvFWAG9nMF3A2Nysw',
#  827: '1nfgCioI15WHlIrPK7UdEl',
#  828: '7279qqlhyNfRk5BBwB0GOh',
#  829: '6gc6oo3u2f7SqTd4mhe81O',
#  830: '1fEwGqdphBrvv5Vx79PjUi',
#  831: '1mMjwoytmHP5dTJbIQxN4V',
#  832: '5ybthCcxHUMyDVcJEGVD0f',
#  833: '1CIylbRdvO5upYoRoy55Hh',
#  834: '5Md89pcwawc564wNKNNG0b',
#  835: '6dP7OHshDvGHaNNSwunol4',
#  836: '2O1JmZHgbLq9ttqx0AqjVm',
#  837: '6EXX0GpVsILp9TGCfu7AVG',
#  838: '26s8LSolLfCIY88ysQbIuT',
#  839: '2ER6CzRUh71rY5K95U9u7m',
#  840: '2mBoEYescv3YHDG5rH6uKd',
#  841: '2G15yxMDE0X3TAr7Di9gd7',
#  842: '4Aixcj6XBhqbdEHDKS7QcH',
#  843: '0rZpNCCYOe06am554MyKRu',
#  844: '3Vszg64mczF1dWEcW2dU5W',
#  845: '3kwoPkICT4iPkNjr6mL13N',
#  846: '6zVybwDdah9DCynv4QOhU0',
#  847: '0PwyYNaSPbVH2toKPEOpNM',
#  848: '4wdliHvRIXiqjWoFfJYe3c',
#  849: '5vP3nmsaGrondXXS5BvrSH',
#  850: '7Jr7XgWFnKQ3mUgbhrVNlx',
#  851: '4FzEKhLeEN58Mu7JzUHdHF',
#  852: '77zgRkcehIGCAtROXkXkb3',
#  853: '6lyYDuLxgcxPLH5RjUPH5p',
#  854: '489r8wlYb7AB29VBjA6vWU',
#  855: '4pQN0GB0fNEEOfQCaWotsY',
#  856: '1ng3xz2dyz57Z1WpnzM2G7',
#  857: '0L0AVjTv84NG5fM9tq4ZR7',
#  858: '4vs7NIU7kZc2Efh6yOGKEZ',
#  859: '21Cqiqu0nBB96GQXvUTphx',
#  860: '0cbL6CYnRqpAxf1evwUVQD',
#  861: '7EPJIXpsTBE9OA3uiO1qm2',
#  862: '7dtYRflRL5xd7mBGraV5tV',
#  863: '5xkQvkqQi2Fb0vL5mA5qRj',
#  864: '2sqrupqcoipb7UzVKApEnJ',
#  865: '4KykZcvg9DXw65YhJrhiOb',
#  866: '656QlXWNjRtnzAr5YNBEQB',
#  867: '1mZtAFuxFAgqmTCqfKLWoj',
#  868: '0BLHMPWOZ2aTI0ZCCbtZem',
#  869: '1JCHKPL04KKnIIp4ANsfvF',
#  870: '1z39BS5hTB0I2kL3w8ux5n',
#  871: '1Nj0wAt4djA9oQbEB7pISM',
#  872: '6UAyCjS0OPMd1Ham8bvs9g',
#  873: '4Q86TvmuqKMwrcY16xiLIT',
#  874: '68ZtcdthScW8ISOvVNW9sV',
#  875: '6Ua3WC8j1AFbXqgll6c2O9',
#  876: '3HajGyV6aBMuSobQf1xbNY',
#  877: '6rJqqRce0Kvo2dJUXoHleC',
#  878: '5tI0Vj2FhioY8AKtEqu9d3',
#  879: '3s0GDsY8I1nwW0j32z6ndv',
#  880: '00gh6kmKYOu8xyorRxQm6a',
#  881: '1W42coQfIlt6btgqpfJWYQ',
#  882: '35kA48fjFobl8mvwr6wIJ0',
#  883: '3HYV4ZdJ1LSOhPo5ehlEqF',
#  884: '69RwhKw37lY73bMGaSts7C',
#  885: '05OMHvPpkWnblSy9Kl7e9l',
#  886: '0ppFjJOvd6dhcpKktp6heM',
#  887: '57XBbHhtTwHKUinVet0o5z',
#  888: '0FLD4kGm4QGRBctAs54CUW',
#  889: '7geL1wsP1998GP0v3QSmDJ',
#  890: '3Dw9w3jnmr58ocgxiwITcq',
#  891: '6kic5bCjlohhDn9KzXbOta',
#  892: '5wnhqlZzXIq8aO9awQO2ND',
#  893: '4Dghr6IbymdYuMDUEybhUR',
#  894: '6xUyErRBtLlykvajZVRkJ8',
#  895: '3RlJ9H0nRhmVPnwwoAY84A',
#  896: '3MyenYlun125t6X8K0rK35',
#  897: '2gXmjQIxCO8lMnSncluZaU',
#  898: '6kVYoiNUDm8zgNteymtW9i',
#  899: '1hKmoQiiol8TjuPz0BdSqz',
#  900: '1PEuL9Ck4xixQEX9bCULvZ',
#  901: '4xnMDfgEmXZEEDdITKcGuE',
#  902: '5KnTqREHfCARDD8im3isVg',
#  903: '6sd3qv6kReAdo6WsLBtXX4',
#  904: '3cJDJfF5k4i9OmE9QWPMSM',
#  905: '38bfc5BSVq6sVAssDmdc8N',
#  906: '3E4pPT8FFrrRJRm3v6k1PG',
#  907: '5EK4wmYHGU15SCSYvnKepf',
#  908: '6sXWE3eSY59H6zy1tiRPue',
#  909: '11sL6ZJmmfutSoWopcXbFm',
#  910: '3ZJhC6cKBtTx6jUJSTr8XI',
#  911: '0Qg8V53QwgXLDtN0xMUL5q',
#  912: '5KTykbPcDB4GYS49jcHbWh',
#  913: '3fr1chTroFCQB2B0m8QdTj',
#  914: '0rS1Y2DkDJhLiaR0MyJyCg',
#  915: '5rrmaoBXZ7Jcs4Qb77j0YA',
#  916: '1xHQO9GJIW9OXHxGBISYc5',
#  917: '6kXp61QMZFPcKMcRPqoiVj',
#  918: '163FlKihIniAXnf9NdoIZk',
#  919: '773p3GT2SYlZUbqTo1nXKI',
#  920: '2iNLGMHL1VHOnUUiGvIEo4',
#  921: '6JJrKpZgPRr78cysPtAyQq',
#  922: '3UV2I2q5F2wTsCjcK3tlhf',
#  923: '4sf3QZW8a3xZ14IGsOAzoy',
#  924: '7yM2WTGITBoapOcAxdovgd',
#  925: '5vGruuHsbTsr6IRtpTDvnK',
#  926: '3YLl0gRlOoj3vRFuFDqYIt',
#  927: '0sPG1Yn8sWnhwDHsUbrU0F',
#  928: '0Dh9PyH7cmX294VQDuNtfo',
#  929: '3aRscMJRah0QrvGE5rkvZl',
#  930: '6iDKe5bQr1XkmNsouyK5Pm',
#  931: '4D4AbYubxEkCbbQ3MV4rfm',
#  932: '2PYzfdTjMDkpIxlOEm3oK2',
#  933: '4rBNfcgIjBo7vHLmby11Aj',
#  934: '2K4pcxTMiwnKoVvdAr5pwD',
#  935: '4iqg3LlZiqAElJOXJtC11H',
#  936: '3TE03r44kXts3yWIKEA3M7',
#  937: '1blIjZIkGoF3sAreSqPM90',
#  938: '7dAlRM3jYjwYIcy6dxmqMN',
#  939: '4167ji2eAk6k9gfVXclNp9',
#  940: '7v3hA4ouFuiWmjuDnquXIR',
#  941: '0EdvGhlC1FkGItLOWQzG4J',
#  942: '0LIll5i3kwo5A3IDpipgkS',
#  943: '4YIMPSc3zZLRwe4Ujaxjce',
#  944: '08DpSTsNFBf1PxTm9lwpXb',
#  945: '1XLjg3NdCEGvgKPdOcj4u3',
#  946: '3MVxFvI9EA03mELd6nTLMH',
#  947: '380fnmlGnkyueBMqGWx2k5',
#  948: '0qDEhyfeFBVihHtyPWCDdh',
#  949: '43mWhBXSflupNLuNjM5vff',
#  950: '59B2CHEMh1to8diq0jB92r',
#  951: '5BWqFYIPTnFx3OPWOoJvmD',
#  952: '6Tlhlskq6kC7dWRQRbqDka',
#  953: '4XfpAjkaS6zinlcan10OBZ',
#  954: '4FEhosRBq1PprpiyQTJtXE',
#  955: '19EXmY8ETqXPinMES14I7q',
#  956: '3mGCLimuzOdod4Lnegny4d',
#  957: '4pxlntE89zyfL0txVloogM',
#  958: '7echw3REDO3lbiYEeD9E6E',
#  959: '4tMZahYVKJdjbC1GHVtNnV',
#  960: '5RfS9o5FOLPdO77H58h3oA',
#  961: '4gQbxC6zdtyklkPO1bDck3',
#  962: '0wmguM6RhXVAX7jqWWCQlK',
#  963: '5xLZ07bX72igG3lX0Xsjni',
#  964: '3D4qYDvoPn5cQxtBm4oseo',
#  965: '5hjhUiwzXZliQMmqqkYT81',
#  966: '5qYbA0I1qwOI3jchiZukHr',
#  967: '1xXeCuBqlolNerPfPVxxvV',
#  968: '0Q4ioaeWOOlKFVPNdFvp9q',
#  969: '4JEj4gtpwF2dnnBZuNwpwT',
#  970: '55RUzsCv2DA6ilOoYYzpbz',
#  971: '7aRd5u0bLGDwfY0mv5sfyy',
#  972: '2h7HrMDoZpWxx3uAuJxyj9',
#  973: '1OQRxZIPriIdtJCs1Dvd8w',
#  974: '7GnX7pGXdWtLObs16B1mFB',
#  975: '4E0cYAmFiAQcJvJK9bbYWW',
#  976: '1wKpMkucynaTfG8lyPprYV',
#  977: '5SLDzWl9xD7bqN154mLi0Y',
#  978: '6JEV3njYMC0x6zPvQftYJr',
#  979: '158sPMKqscbRm6WqR3P3Ev',
#  980: '0f14r70OISSfJoyqYaHbgV',
#  981: '6nRxfBhqFVf7YBzop6laRH',
#  982: '4a9fV4pX4MheSOpPfgYuo3',
#  983: '7lmORDwDLPMdqLyMh2uH8v',
#  984: '320EPCSEezHt1rtbfwH6Ck',
#  985: '6GnLE3Ncm59wsLSqF9divg',
#  986: '6ioeKDb6o2o3QMyxTXcvM7',
#  987: '2hkP6QHEvx27CJ8VOJF7JD',
#  988: '08b8bBBm9g4yIou2ESJmQN',
#  989: '0rW6fVd3yuW2CF2sLYWQtE',
#  990: '0zfT626RwO6zN3RDYeRit5',
#  991: '3gnrmLahFhVXRI9DA1MImH',
#  992: '2jn2poSb6Rz87CA1fXSWtb',
#  993: '30wki8WYREGLQPm623vzkZ',
#  994: '5bRQz4QFmvY0UgEySM1S7J',
#  995: '34OfCIgv73WN6WhYvBktB1',
#  996: '3TVzK3Dw7UCXu2cEUEUj2x',
#  997: '51WugiwSgDDCfX7wmdoZ4X',
#  998: '65C6Unk7nhg2aCnVuAPMo8',
#  999: '63aKrG0w6Zkh3pugZvCDAy',
#  ...}

# %%
artists_map_inv= {v:i for i,v in artists_map.items()}
artists_map_inv
# Out:
# {'2d6NCBac0YDM7UthnFGPYz': 0,
#  '1XVbGKrwpq5PkEbOX2z5mg': 1,
#  '4zMX9gWf1DKhvsYHUCbBF7': 2,
#  '2eJkpFtB62y7qCx27DDNGY': 3,
#  '6XUNUZVWpFql1ysNCVvsNS': 4,
#  '4kL2OPLMiNMXhojqQSNkUQ': 5,
#  '7tz4b7x6DwHILd1J9qj1vv': 6,
#  '2qc41rNTtdLK0tV3mJn2Pm': 7,
#  '4iPR84F8j5agZmhHwUdlPK': 8,
#  '5yjbUO1Jocui7RKE30zfLT': 9,
#  '470SGea4tIbGLTpKcYJfLx': 10,
#  '7kDENNLAOgnizz0fgUB6PX': 11,
#  '39RGo9NOqiCfbV8epXxFTj': 12,
#  '6rxxu32JCGDpKKMPHxnSJp': 13,
#  '2k7En28V8aLSsxAxE4nQdF': 14,
#  '7lkaHYkz51sDosEghtLxjp': 15,
#  '0YIhVMmaboWI25NVbZRkmo': 16,
#  '1DXylZlWbVvlckNqwvjTEt': 17,
#  '7GJMYx9DymhkSu7T75jXur': 18,
#  '1APhKAeROy02DedkHnbrXb': 19,
#  '5ndkK3dpZLKtBklKjxNQwT': 20,
#  '2PQ9UX4kWDE3mf2fYGRzqF': 21,
#  '2uTWduJySVvAw3B3KOJYxT': 22,
#  '5aBxFPaaGk9204ssHUvXWN': 23,
#  '5sQJzc7ZGwC4olbhp2kqqX': 24,
#  '35umDvKBwo2nG53FZTAVui': 25,
#  '1wUmdemiR9Dxw8A2el365A': 26,
#  '6nxwdNlg4g7FrLZZB43n5v': 27,
#  '10exVja0key0uqUkk6LJRT': 28,
#  '5ikCQkCt3TiuYYiLLffYL8': 29,
#  '046RRGSoYRQ7qIKliJJSNS': 30,
#  '7obdmuirClkgU94pcUy05m': 31,
#  '09b5OcuIELTdD7FfzQzcdB': 32,
#  '58F5GqfOMje69JMa2LIHD6': 33,
#  '6QAd9ZxH3ptahZeWoqKks4': 34,
#  '3xU0xHtoERRI2puwRtswLb': 35,
#  '2mAYpnSe3g2Y22JcZ2ddku': 36,
#  '2yS8NRKo6SMDqCERBV9pSd': 37,
#  '0WhGV9lzljq2QKJ8ipw6jx': 38,
#  '6tgChgEXkgpoJqmmoFkH44': 39,
#  '5wB608tPwPakD0LQunieYt': 40,
#  '7efkoQb7dW8884GCnykYKW': 41,
#  '5gVgcz9X3QcrcrrDXR56NP': 42,
#  '77C3owGTFPmigDDIpQLoiF': 43,
#  '1OpyZDaOsvR1SAYU4RXB5y': 44,
#  '4ePunOqQbOYoQwd1298g3Z': 45,
#  '09UQUOICiqSgc3C8TRhTEh': 46,
#  '3mGCLimuzOdod4Lnegny4d': 956,
#  '4pxlntE89zyfL0txVloogM': 957,
#  '7echw3REDO3lbiYEeD9E6E': 958,
#  '4tMZahYVKJdjbC1GHVtNnV': 959,
#  '5RfS9o5FOLPdO77H58h3oA': 960,
#  '4gQbxC6zdtyklkPO1bDck3': 961,
#  '0wmguM6RhXVAX7jqWWCQlK': 962,
#  '5xLZ07bX72igG3lX0Xsjni': 963,
#  '3D4qYDvoPn5cQxtBm4oseo': 964,
#  '5hjhUiwzXZliQMmqqkYT81': 965,
#  '5qYbA0I1qwOI3jchiZukHr': 966,
#  '1xXeCuBqlolNerPfPVxxvV': 967,
#  '0Q4ioaeWOOlKFVPNdFvp9q': 968,
#  '4JEj4gtpwF2dnnBZuNwpwT': 969,
#  '55RUzsCv2DA6ilOoYYzpbz': 970,
#  '7aRd5u0bLGDwfY0mv5sfyy': 971,
#  '2h7HrMDoZpWxx3uAuJxyj9': 972,
#  '1OQRxZIPriIdtJCs1Dvd8w': 973,
#  '7GnX7pGXdWtLObs16B1mFB': 974,
#  '4E0cYAmFiAQcJvJK9bbYWW': 975,
#  '1wKpMkucynaTfG8lyPprYV': 976,
#  '5SLDzWl9xD7bqN154mLi0Y': 977,
#  '6JEV3njYMC0x6zPvQftYJr': 978,
#  '158sPMKqscbRm6WqR3P3Ev': 979,
#  '0f14r70OISSfJoyqYaHbgV': 980,
#  '6nRxfBhqFVf7YBzop6laRH': 981,
#  '4a9fV4pX4MheSOpPfgYuo3': 982,
#  '7lmORDwDLPMdqLyMh2uH8v': 983,
#  '320EPCSEezHt1rtbfwH6Ck': 984,
#  '6GnLE3Ncm59wsLSqF9divg': 985,
#  '6ioeKDb6o2o3QMyxTXcvM7': 986,
#  '2hkP6QHEvx27CJ8VOJF7JD': 987,
#  '08b8bBBm9g4yIou2ESJmQN': 988,
#  '0rW6fVd3yuW2CF2sLYWQtE': 989,
#  '0zfT626RwO6zN3RDYeRit5': 990,
#  '3gnrmLahFhVXRI9DA1MImH': 991,
#  '2jn2poSb6Rz87CA1fXSWtb': 992,
#  '30wki8WYREGLQPm623vzkZ': 993,
#  '5bRQz4QFmvY0UgEySM1S7J': 994,
#  '34OfCIgv73WN6WhYvBktB1': 995,
#  '3TVzK3Dw7UCXu2cEUEUj2x': 996,
#  '51WugiwSgDDCfX7wmdoZ4X': 997,
#  '65C6Unk7nhg2aCnVuAPMo8': 998,
#  '63aKrG0w6Zkh3pugZvCDAy': 999,
#  ...}

# %% [markdown]
# ### Function to see examples of collaborations

# %%
def get_artist_name(artist_key, artist_map_):
    artist_code= artist_map_[artist_key].item()
    artist_code= artists_map[artist_code]
    artist_df= artist_info_df[artist_info_df['artist_code']==artist_code]
    return artist_df['artist_name'].values[0], artist_df['popularity'].values[0]

# %%
def get_collab_song_from_artists(artist1_key, artist2_key, artist_map_):
    artist1_code= artist_map_[artist1_key].item()
    artist1_code= artists_map[artist1_code]
    
    artist2_code= artist_map_[artist2_key].item()
    artist2_code= artists_map[artist2_code]
    
    df= collab_tracks[collab_tracks['artist_id'].map(lambda x: (artist1_code in x) and (artist2_code in x))]
    if not df.empty:
        return df['track_id release_date genres'.split()]
    else:
        return None

# %% [markdown]
# ## Define model

# %%
def complete_snapshot(snapshot, filter_edges=True):
    data= snapshot.clone()

    data['song'].num_nodes= daily_dataset['features']['tracks.num_nodes']
    data['song'].x= daily_dataset['features']['tracks.x'].clone()
    data['song'].node_id= daily_dataset['features']['tracks.node_id'].clone()

    data['artist'].num_nodes= daily_dataset['features']['artist.num_nodes']
    data['artist'].x= daily_dataset['features']['artist.x'].clone()
    data['artist'].node_id= daily_dataset['features']['artist.node_id'].clone()

    data['genre'].num_nodes= daily_dataset['features']['genre.num_nodes']
    data['genre'].x= daily_dataset['features']['genre.x'].clone()
    data['genre'].node_id= daily_dataset['features']['genre.node_id'].clone()
    
    if filter_edges:
    
        ##*********Filter new edges
        #Filter artist_produce_song
        t= data["artist", "newproduce", "song"].edge_index.T
        artist_songs_df= pd.DataFrame(t.numpy())
        t2= data["artist", "newcollaborate", "artist"].edge_index.T
        df2= pd.DataFrame(t2.numpy())
        target_artists= set(df2[0].unique().tolist() + df2[1].unique().tolist())
        artist_songs_df= artist_songs_df[(artist_songs_df[0].isin(target_artists))]
        edge_index= torch.tensor(artist_songs_df.values).T
        data["artist", "newproduce", "song"].edge_index= edge_index

        #Filter song_has_genre
        t= data["song", "newhas", "genre"].edge_index.T
        song_genres_df= pd.DataFrame(t.numpy())
        target_songs= artist_songs_df[1].values#df2[1].unique().tolist()
        song_genres_df= song_genres_df[(song_genres_df[0].isin(target_songs))]
        edge_index= torch.tensor(song_genres_df.values).T    
        data["song", "newhas", "genre"].edge_index= edge_index

        #Filter artist_has_genre edges
        t= data["artist", "newhas", "genre"].edge_index.T
        artist_genres_df= pd.DataFrame(t.numpy())
        t2= data["artist", "newcollaborate", "artist"].edge_index.T
        df2= pd.DataFrame(t2.numpy())
        target_artists= set(df2[0].unique().tolist() + df2[1].unique().tolist())
        artist_genres_df= artist_genres_df[(artist_genres_df[0].isin(target_artists))]
        edge_index= torch.tensor(artist_genres_df.values).T
        data["artist", "newhas", "genre"].edge_index= edge_index

        ##*********Filter all edges

        #Filter artist_produce_song
        t= data["artist", "produce", "song"].edge_index.T
        artist_songs_df= pd.DataFrame(t.numpy())
        t2= data["artist", "collaborate", "artist"].edge_index.T
        df2= pd.DataFrame(t2.numpy())
        target_artists= set(df2[0].unique().tolist() + df2[1].unique().tolist())
        artist_songs_df= artist_songs_df[(artist_songs_df[0].isin(target_artists))]
        edge_index= torch.tensor(artist_songs_df.values).T
        data["artist", "produce", "song"].edge_index= edge_index

        #Filter song_has_genre
        t= data["song", "has", "genre"].edge_index.T
        song_genres_df= pd.DataFrame(t.numpy())
        song_genres_df= song_genres_df.drop_duplicates(0, keep='first')
        target_songs= artist_songs_df[1].values#df2[1].unique().tolist()
        song_genres_df= song_genres_df[(song_genres_df[0].isin(target_songs))]
        edge_index= torch.tensor(song_genres_df.values).T    
        data["song", "has", "genre"].edge_index= edge_index

        #Filter artist_has_genre edges
        t= data["artist", "has", "genre"].edge_index.T
        artist_genres_df= pd.DataFrame(t.numpy())
        t2= data["artist", "collaborate", "artist"].edge_index.T
        df2= pd.DataFrame(t2.numpy())
        target_artists= set(df2[0].unique().tolist() + df2[1].unique().tolist())
        artist_genres_df= artist_genres_df[(artist_genres_df[0].isin(target_artists))]
        edge_index= torch.tensor(artist_genres_df.values).T
        data["artist", "has", "genre"].edge_index= edge_index

        ##*********Filter reverse edges

        #Filter artist_produce_song
        t= data["song", "rev_produce", "artist"].edge_index.T
        artist_songs_df= pd.DataFrame(t.numpy())
        t2= data["artist", "rev_collaborate", "artist"].edge_index.T
        df2= pd.DataFrame(t2.numpy())
        target_artists= set(df2[1].unique().tolist() + df2[1].unique().tolist())
        artist_songs_df= artist_songs_df[(artist_songs_df[1].isin(target_artists))]
        edge_index= torch.tensor(artist_songs_df.values).T
        data["song", "rev_produce", "artist"].edge_index= edge_index

        #Filter song_has_genre
        t= data["genre", "rev_has", "song"].edge_index.T
        song_genres_df= pd.DataFrame(t.numpy())
        target_songs= artist_songs_df[0].values
        song_genres_df= song_genres_df[(song_genres_df[1].isin(target_songs))]
        edge_index= torch.tensor(song_genres_df.values).T    
        data["genre", "rev_has", "song"].edge_index= edge_index

        #Filter artist_has_genre edges
        t= data["genre", "rev_has", "artist"].edge_index.T
        artist_genres_df= pd.DataFrame(t.numpy())
        t2= data["artist", "rev_collaborate", "artist"].edge_index.T
        df2= pd.DataFrame(t2.numpy())
        target_artists= set(df2[0].unique().tolist() + df2[1].unique().tolist())
        artist_genres_df= artist_genres_df[(artist_genres_df[1].isin(target_artists))]
        edge_index= torch.tensor(artist_genres_df.values).T
        data["genre", "rev_has", "artist"].edge_index= edge_index

        #********* Filter reverse new edges ***************
         #Filter artist_produce_song
        t= data["song", "rev_newproduce", "artist"].edge_index.T
        artist_songs_df= pd.DataFrame(t.numpy())
        t2= data["artist", "rev_newcollaborate", "artist"].edge_index.T
        df2= pd.DataFrame(t2.numpy())
        target_artists= set(df2[1].unique().tolist() + df2[1].unique().tolist())
        artist_songs_df= artist_songs_df[(artist_songs_df[1].isin(target_artists))]
        edge_index= torch.tensor(artist_songs_df.values).T
        data["song", "rev_newproduce", "artist"].edge_index= edge_index

        #Filter song_has_genre
        t= data["genre", "rev_newhas", "song"].edge_index.T
        song_genres_df= pd.DataFrame(t.numpy())
        target_songs= artist_songs_df[0].values
        song_genres_df= song_genres_df[(song_genres_df[1].isin(target_songs))]
        edge_index= torch.tensor(song_genres_df.values).T    
        data["genre", "rev_newhas", "song"].edge_index= edge_index

        #Filter artist_has_genre edges
        t= data["genre", "rev_newhas", "artist"].edge_index.T
        artist_genres_df= pd.DataFrame(t.numpy())
        t2= data["artist", "rev_newcollaborate", "artist"].edge_index.T
        df2= pd.DataFrame(t2.numpy())
        target_artists= set(df2[0].unique().tolist() + df2[1].unique().tolist())
        artist_genres_df= artist_genres_df[(artist_genres_df[1].isin(target_artists))]
        edge_index= torch.tensor(artist_genres_df.values).T
        data["genre", "rev_newhas", "artist"].edge_index= edge_index   
    
    return data

def generate_new_edges_snapshot(snapshot):
    data= HeteroData()
    
    data['song'].num_nodes= snapshot['song'].num_nodes
    data['song'].x= snapshot['song'].x.clone()
    data['song'].node_id= snapshot['song'].node_id.clone()

    data['artist'].num_nodes= snapshot['artist'].num_nodes
    data['artist'].x= snapshot['artist'].x.clone()
    data['artist'].node_id= snapshot['artist'].node_id.clone()

    data['genre'].num_nodes= snapshot['genre'].num_nodes
    data['genre'].x= snapshot['genre'].x.clone()
    data['genre'].node_id= snapshot['genre'].node_id.clone()
    
    data["artist", "newproduce", "song"].edge_index= snapshot["artist", "newproduce", "song"].edge_index.clone()
    data["artist", "newcollaborate", "artist"].edge_index= snapshot["artist", "newcollaborate", "artist"].edge_index.clone()
    data["artist", "newhas", "genre"].edge_index= snapshot["artist", "newhas", "genre"].edge_index.clone()
    data["song", "newhas", "genre"].edge_index= snapshot["song", "newhas", "genre"].edge_index.clone()

    data["song", "rev_newproduce", "artist"].edge_index= snapshot["song", "rev_newproduce", "artist"].edge_index.clone()
    data["artist", "rev_newcollaborate", "artist"].edge_index= snapshot["artist", "rev_newcollaborate", "artist"].edge_index.clone()
    data["genre", "rev_newhas", "artist"].edge_index= snapshot["genre", "rev_newhas", "artist"].edge_index.clone()
    data["genre", "rev_newhas", "song"].edge_index= snapshot["genre", "rev_newhas", "song"].edge_index.clone()

    return data

def generate_all_edges_snapshot(snapshot):
    data= HeteroData()
    
    data['song'].num_nodes= snapshot['song'].num_nodes
    data['song'].x= snapshot['song'].x.clone()
    data['song'].node_id= snapshot['song'].node_id.clone()

    data['artist'].num_nodes= snapshot['artist'].num_nodes
    data['artist'].x= snapshot['artist'].x.clone()
    data['artist'].node_id= snapshot['artist'].node_id.clone()

    data['genre'].num_nodes= snapshot['genre'].num_nodes
    data['genre'].x= snapshot['genre'].x.clone()
    data['genre'].node_id= snapshot['genre'].node_id.clone()
    
    data["artist", "produce", "song"].edge_index= snapshot["artist", "produce", "song"].edge_index.clone()
    data["artist", "collaborate", "artist"].edge_index= snapshot["artist", "collaborate", "artist"].edge_index.clone()
    data["artist", "has", "genre"].edge_index= snapshot["artist", "has", "genre"].edge_index.clone()
    data["song", "has", "genre"].edge_index= snapshot["song", "has", "genre"].edge_index.clone()

    data["song", "rev_produce", "artist"].edge_index= snapshot["song", "rev_produce", "artist"].edge_index.clone()
    data["artist", "rev_collaborate", "artist"].edge_index= snapshot["artist", "rev_collaborate", "artist"].edge_index.clone()
    data["genre", "rev_has", "artist"].edge_index= snapshot["genre", "rev_has", "artist"].edge_index.clone()
    data["genre", "rev_has", "song"].edge_index= snapshot["genre", "rev_has", "song"].edge_index.clone()

    return data

# %%
"""
data=daily_dataset['edges'][0].clone()
complete_data= complete_snapshot(data)
data_time_evol= generate_new_edges_snapshot(complete_data)
data_global= generate_all_edges_snapshot(complete_data)
data_time_evol.metadata(), data_global.metadata()
"""
# Out:
# "\ndata=daily_dataset['edges'][0].clone()\ncomplete_data= complete_snapshot(data)\ndata_time_evol= generate_new_edges_snapshot(complete_data)\ndata_global= generate_all_edges_snapshot(complete_data)\ndata_time_evol.metadata(), data_global.metadata()\n"

# %%
class TimeEvolGNN(torch.nn.Module):
    def __init__(self, node_feature_dict, metadata, num_output_features):
        super(TimeEvolGNN, self).__init__()
        self.recurrent = HeteroGCLSTM(node_feature_dict, num_output_features, metadata)
    
    def forward(self, x_dict, edge_index_dict, h_dict, c_dict):
        h_0, c_0 = self.recurrent(x_dict, edge_index_dict)# h_dict, c_dict)
        h=h_0
        return h, h_0, c_0
    
class GlobalGNN(torch.nn.Module):
    def __init__(self, num_output_features):
        super(GlobalGNN, self).__init__()
        self.conv= SAGEConv((-1,-1), num_output_features)
    
    def forward(self, x_dict, edge_index_dict):
        x= self.conv(x_dict, edge_index_dict)#.relu()
        return x
    
class GlobalGNNwithAttention(torch.nn.Module):
    def __init__(self, num_output_features, n_heads=4):
        super(GlobalGNNwithAttention, self).__init__()
        self.conv= GATv2Conv((-1,-1), num_output_features, add_self_loops=False, heads=n_heads, concat=True)
        self.linear= torch.nn.Linear(num_output_features*n_heads,num_output_features)
    
    def forward(self, x_dict, edge_index_dict):
        x= self.conv(x_dict, edge_index_dict)
        return x

# %%
class HeteroEvolGNN3(torch.nn.Module):
    def __init__(self, node_feature_dict, metadata_time_evol, metadata_global, num_output_features):
        super(HeteroEvolGNN3, self).__init__()
        
        self.time_evol_gnn = TimeEvolGNN(node_feature_dict, metadata_time_evol, num_output_features)
        
        self.global_gnn = GlobalGNN(num_output_features)
        self.global_gnn = to_hetero(self.global_gnn, metadata_global)
        
        self.linears= ModuleDict({v:torch.nn.Linear(num_output_features,num_output_features) for v,i in node_feature_dict.items()})
        
        self.norms= ModuleDict({v:BatchNorm(num_output_features) for v,i in node_feature_dict.items()})
        
        self.global_gnn_with_att= GlobalGNNwithAttention(num_output_features)
        self.global_gnn_with_att = to_hetero(self.global_gnn_with_att, metadata_global)
        
    def forward(self, graph_evol, graph_global, h_dict=None, c_dict=None):
        
        time_emb, h, c = self.time_evol_gnn(graph_evol.x_dict, graph_evol.edge_index_dict, h_dict, c_dict)
        agg_emb = self.global_gnn(graph_global.x_dict, graph_global.edge_index_dict) 
        
        global_emb= {key: torch.add(time_emb[key],agg_emb[key]) for key, value in time_emb.items()}
        
        global_emb= {k: norm(global_emb[k]) for k, norm in self.norms.items()}
        global_emb= {k: lin(global_emb[k]) for k, lin in self.linears.items()}
        global_emb = {key: val.relu() for key, val in global_emb.items()}   

        final_emb= self.global_gnn_with_att(global_emb, graph_global.edge_index_dict) 

        return final_emb, h, c
    
class HeteroEvolGNNWithTimeOnly(torch.nn.Module):
    def __init__(self, node_feature_dict, metadata_time_evol, metadata_global, num_output_features):
        super(HeteroEvolGNNWithTimeOnly, self).__init__()
        
        self.time_evol_gnn = TimeEvolGNN(node_feature_dict, metadata_time_evol, num_output_features)
        
        self.linears= ModuleDict({v:torch.nn.Linear(num_output_features,num_output_features) for v,i in node_feature_dict.items()})
        self.norms= ModuleDict({v:BatchNorm(num_output_features) for v,i in node_feature_dict.items()})
        
        self.global_gnn_with_att= GlobalGNNwithAttention(num_output_features)
        self.global_gnn_with_att = to_hetero(self.global_gnn_with_att, metadata_global)
        
    def forward(self, graph_evol, graph_global, h_dict=None, c_dict=None):
        
        time_emb, h, c = self.time_evol_gnn(graph_evol.x_dict, graph_evol.edge_index_dict, h_dict, c_dict)
        
        global_emb= {k: norm(time_emb[k]) for k, norm in self.norms.items()}
        global_emb= {k: lin(global_emb[k]) for k, lin in self.linears.items()}
        global_emb = {key: val.relu() for key, val in global_emb.items()}   

        final_emb= self.global_gnn_with_att(global_emb, graph_global.edge_index_dict) 

        return final_emb, h, c
    
class HeteroEvolGNNWithAggOnly(torch.nn.Module):
    def __init__(self, node_feature_dict, metadata_time_evol, metadata_global, num_output_features):
        super(HeteroEvolGNNWithAggOnly, self).__init__()
                
        self.global_gnn = GlobalGNN(num_output_features)
        self.global_gnn = to_hetero(self.global_gnn, metadata_global)
        
        self.linears= ModuleDict({v:torch.nn.Linear(num_output_features,num_output_features) for v,i in node_feature_dict.items()})
        
        self.norms= ModuleDict({v:BatchNorm(num_output_features) for v,i in node_feature_dict.items()})
        
        self.global_gnn_with_att= GlobalGNNwithAttention(num_output_features)
        self.global_gnn_with_att = to_hetero(self.global_gnn_with_att, metadata_global)
        
    def forward(self, graph_evol, graph_global, h_dict=None, c_dict=None):
        
        agg_emb = self.global_gnn(graph_global.x_dict, graph_global.edge_index_dict) 
                
        global_emb= {k: norm(agg_emb[k]) for k, norm in self.norms.items()}
        global_emb= {k: lin(global_emb[k]) for k, lin in self.linears.items()}
        global_emb = {key: val.relu() for key, val in global_emb.items()}   

        final_emb= self.global_gnn_with_att(global_emb, graph_global.edge_index_dict) 

        return final_emb, None, None

# %%
out_channels= 320
node_feature_dict= {'song':9, 'artist':2, 'genre':1}

# %% [markdown]
# ### Train model

# %%
def sample_negative_edges(positive_edges, n_nodes, n_samples):
    
    edges_= np.vstack((positive_edges[0],positive_edges[1])).T
    
    origins = []
    dest = []
    #Here we generate a negative link for each node in the snapshot
    for i in range(n_samples):
        
        o_node= np.random.randint(n_nodes)
        d_node= np.random.randint(n_nodes)

        edge_is_new= (len(edges_[(edges_[:,0]==o_node) & (edges_[:,1]==d_node)])==0)
        
        #If the (o_node, d_node) tuple already exists, try again...
        while not edge_is_new:
            d_node= np.random.randint(n_nodes)
        
            edge_is_new= (len(edges_[(edges_[:,0]==o_node) & (edges_[:,1]==d_node)])==0)

        origins.append(o_node)
        dest.append(d_node)
        
    edge_index_negs = torch.row_stack([torch.LongTensor(origins), torch.LongTensor(dest)])
    edge_label_negs= torch.zeros(edge_index_negs.shape[1]).reshape(-1,1).float()
    
    return edge_index_negs, edge_label_negs

# %%
def generate_node_embeddings(gnn_type, gnn_, new_edges, all_edges, h_dict=None, c_dict=None):
    
    emb_= None
    if gnn_type in 'PRESTO_full PRESTO_time_only PRESTO_agg_only'.split():
        emb_, h_dict, c_dict= gnn_(new_edges, all_edges, h_dict, c_dict)
    elif gnn_type=='time_only':
        emb_, h_dict, c_dict= gnn_(new_edges.x_dict, new_edges.edge_index_dict, h_dict, c_dict)
    elif gnn_type in 'agg_only attention_only'.split():
        emb_ = gnn_(all_edges.x_dict, all_edges.edge_index_dict)
        
    return emb_, h_dict, c_dict

# %%
def sample_heterograph_v2(hetero_graph, nodes_to_sample=0.15):
    num_artist_to_sample= int(len(hetero_graph['artist'].node_id)* nodes_to_sample)  
    #artists_to_sample,_= torch.sort(torch.tensor(np.random.choice(hetero_graph['artist'].node_id,num_artist_to_sample)))

    num_songs_to_sample= int(len(hetero_graph['song'].node_id)* 0.05)                                    
    songs_to_sample,_= torch.sort(torch.tensor(np.random.choice(hetero_graph['song'].node_id,num_songs_to_sample)))
 
    num_genres_to_sample= int(len(hetero_graph['genre'].node_id)*nodes_to_sample)                                    
    genres_to_sample,_= torch.sort(torch.tensor(np.random.choice(hetero_graph['genre'].node_id,num_genres_to_sample)))
    
       
    src_unique= hetero_graph.edge_index_dict[('artist', 'targetcollaborate', 'artist')][0]
    dst_unique= hetero_graph.edge_index_dict[('artist', 'targetcollaborate', 'artist')][1]
    
    artists_to_sample = torch.unique(torch.stack([src_unique, dst_unique,], dim=1))
    
    subset_dict = {
        'genre': genres_to_sample,
        'artist':artists_to_sample,
        'song': songs_to_sample,
    }
        
    data =  HeteroData()
    
    for node_type, subset in subset_dict.items():
        #print(subset)
        for key, value in hetero_graph[node_type].items():
            if key == 'num_nodes':
                if subset.dtype == torch.bool:
                    data[node_type].num_nodes = int(subset.sum())
                else:
                    data[node_type].num_nodes = subset.size(0)
            elif hetero_graph[node_type].is_node_attr(key):
                data[node_type][key] = value[subset]
            else:
                data[node_type][key] = value
   
    for edge_type in hetero_graph.edge_types:
        #print('edge_type', edge_type)
        src, _, dst = edge_type
        if src not in subset_dict or dst not in subset_dict:
            continue

     
        edge_index= hetero_graph[edge_type].edge_index
        
        new_edge_label=[]
        new_edge_index_src=[]
        new_edge_index_dst=[]
        for i in range(len(edge_index[0])):
            src_edge_index= np.where(subset_dict[src]==edge_index[0][i])[0]
            dst_edge_index= np.where(subset_dict[dst]==edge_index[1][i])[0]
            
            if (len(src_edge_index)>0) and (len(dst_edge_index)>0):
                src_edge_index= src_edge_index[0]
                dst_edge_index= dst_edge_index[0]
                new_edge_index_src.append(src_edge_index)
                new_edge_index_dst.append(dst_edge_index)
                new_edge_label.append(hetero_graph[edge_type].edge_label[i])
                
        #print(new_edge_index_src, new_edge_index_dst)
        new_edge_index = torch.stack([torch.tensor(new_edge_index_src, dtype=torch.long), 
                                      torch.tensor(new_edge_index_dst, dtype=torch.long),], dim=0)
        data[edge_type].edge_index= new_edge_index
        data[edge_type].edge_label= torch.tensor(new_edge_label).reshape(-1,1)

    return subset_dict, data

# %%
def sample_heterograph(hetero_graph, nodes_to_sample=0.15):
    num_artist_to_sample= int(len(hetero_graph['artist'].node_id)* nodes_to_sample)  
    artists_to_sample,_= torch.sort(torch.tensor(np.random.choice(hetero_graph['artist'].node_id,num_artist_to_sample)))

    num_songs_to_sample= int(len(hetero_graph['song'].node_id)* nodes_to_sample)                                    
    songs_to_sample,_= torch.sort(torch.tensor(np.random.choice(hetero_graph['song'].node_id,num_songs_to_sample)))
 
    num_genres_to_sample= int(len(hetero_graph['genre'].node_id)*nodes_to_sample)                                    
    genres_to_sample,_= torch.sort(torch.tensor(np.random.choice(hetero_graph['genre'].node_id,num_genres_to_sample)))
    
    subset_dict = {
        'genre': genres_to_sample,
        'artist':artists_to_sample,
        'song': songs_to_sample,
    }
    
       
    data =  HeteroData()

    for node_type, subset in subset_dict.items():
        #print(subset)
        for key, value in hetero_graph[node_type].items():
            if key == 'num_nodes':
                if subset.dtype == torch.bool:
                    data[node_type].num_nodes = int(subset.sum())
                else:
                    data[node_type].num_nodes = subset.size(0)
            elif hetero_graph[node_type].is_node_attr(key):
                data[node_type][key] = value[subset]
            else:
                data[node_type][key] = value
   
    for edge_type in hetero_graph.edge_types:
        #print('edge_type', edge_type)
        src, _, dst = edge_type
        if src not in subset_dict or dst not in subset_dict:
            continue

     
        edge_index= hetero_graph[edge_type].edge_index
        
        new_edge_label=[]
        new_edge_index_src=[]
        new_edge_index_dst=[]
        for i in range(len(edge_index[0])):
            src_edge_index= np.where(subset_dict[src]==edge_index[0][i])[0]
            dst_edge_index= np.where(subset_dict[dst]==edge_index[1][i])[0]
            
            if (len(src_edge_index)>0) and (len(dst_edge_index)>0):
                src_edge_index= src_edge_index[0]
                dst_edge_index= dst_edge_index[0]
                new_edge_index_src.append(src_edge_index)
                new_edge_index_dst.append(dst_edge_index)
                new_edge_label.append(hetero_graph[edge_type].edge_label[i])
                
        #print(new_edge_index_src, new_edge_index_dst)
        new_edge_index = torch.stack([torch.tensor(new_edge_index_src, dtype=torch.long), 
                                      torch.tensor(new_edge_index_dst, dtype=torch.long),], dim=0)
        data[edge_type].edge_index= new_edge_index
        data[edge_type].edge_label= torch.tensor(new_edge_label).reshape(-1,1)
        """    
        edge_index, _, edge_mask = bipartite_subgraph(
            (subset_dict[src], subset_dict[dst]),
            hetero_graph[edge_type].edge_index,
            relabel_nodes=True,
            size=(hetero_graph[src].node_id.max()+1, hetero_graph[dst].node_id.max()+1),
            return_edge_mask=True,
        )

        
        for key, value in hetero_graph[edge_type].items():
            if key == 'edge_index':
                data[edge_type].edge_index = edge_index
            elif hetero_graph[edge_type].is_edge_attr(key):
                data[edge_type][key] = value[edge_mask]
            else:
                data[edge_type][key] = value
        """
    return subset_dict, data

    """
    
    data = copy.copy(hetero_graph)
        
    for node_type, subset in subset_dict.items():

        if subset.dtype == torch.bool:
            num_nodes = int(subset.sum())
        else:
            num_nodes = subset.size(0)
            subset = torch.unique(subset, sorted=True)
            subset_dict[node_type] = subset

        for key, value in data[node_type].items():
            if key == 'num_nodes':
                data[node_type].num_nodes = num_nodes
            elif data[node_type].is_node_attr(key):
                data[node_type][key] = value[subset]
            else:
                data[node_type][key] = value

    for edge_type in data.edge_types:
        src, _, dst = edge_type

        src_subset = subset_dict.get(src)
        if src_subset is None:
            src_subset = torch.arange(data[src].num_nodes)
        dst_subset = subset_dict.get(dst)
        if dst_subset is None:
            dst_subset = torch.arange(data[dst].num_nodes)

        #print(edge_type, src_subset, dst_subset)
        #print(hetero_graph['artist'].num_nodes)
        edge_index, _, edge_mask = bipartite_subgraph(
            (src_subset, dst_subset),
            data[edge_type].edge_index,
            relabel_nodes=False,
            size=(src_subset.max()+1, dst_subset.max()+1),
            return_edge_mask=True,
        )

        for key, value in data[edge_type].items():
            if key == 'edge_index':
                data[edge_type].edge_index = edge_index
            elif data[edge_type].is_edge_attr(key):
                data[edge_type][key] = value[edge_mask]
            else:
                data[edge_type][key] = value

    return data
    
    """

def bipartite_subgraph(
    subset: Union[PairTensor, Tuple[List[int], List[int]]],
    edge_index: Tensor,
    edge_attr: OptTensor = None,
    relabel_nodes: bool = False,
    size: Optional[Tuple[int, int]] = None,
    return_edge_mask: bool = False,
) -> Union[Tuple[Tensor, OptTensor], Tuple[Tensor, OptTensor, OptTensor]]:

    device = edge_index.device

    src_subset, dst_subset = subset
    print('subsets', src_subset, dst_subset)
    if src_subset.dtype != torch.bool:
        src_size = int(edge_index[0].max()) + 1 if size is None else size[0]
        src_node_mask = index_to_mask(src_subset, size=src_size)
    else:
        src_size = src_subset.size(0)
        src_node_mask = src_subset

    if dst_subset.dtype != torch.bool:
        dst_size = int(edge_index[1].max()) + 1 if size is None else size[1]
        dst_node_mask = index_to_mask(dst_subset, size=dst_size)
    else:
        dst_size = dst_subset.size(0)
        dst_node_mask = dst_subset

    print("edge_index 0", edge_index)
    edge_mask = src_node_mask[edge_index[0]] & dst_node_mask[edge_index[1]]
    print('edge_mask', edge_mask)

    edge_index = edge_index[:, edge_mask]
    edge_attr = edge_attr[edge_mask] if edge_attr is not None else None
    print(edge_index)

    if edge_index.shape[1]>0:
        if relabel_nodes:
            node_idx_i = edge_index.new_zeros(src_node_mask.size(0))
            node_idx_j = edge_index.new_zeros(dst_node_mask.size(0))
            print(src_subset.shape, src_node_mask.shape, src_node_mask.sum())
            node_idx_i[src_subset] = torch.arange(int(src_node_mask.sum()),
                                                  device=node_idx_i.device)
            node_idx_j[dst_subset] = torch.arange(int(dst_node_mask.sum()),
                                                  device=node_idx_j.device)
            edge_index = torch.stack([
                node_idx_i[edge_index[0]],
                node_idx_j[edge_index[1]],
            ], dim=0)

    if return_edge_mask:
        return edge_index, edge_attr, edge_mask
    else:
        return edge_index, edge_attr

# %%
sigm= torch.nn.Sigmoid()

device = 'cpu' 
n_epochs= 1#120
seq_len=12

batch_size_=512
batch_n_nodes= 180

loss_fn=  F.torch.nn.BCEWithLogitsLoss()

#model_types= 'PRESTO_full PRESTO_time_only PRESTO_agg_only time_only agg_only attention_only'.split()
model_types= 'PRESTO_full'.split()

#T= 12
#T_size=6
time_window_size= 30 #days
displayed_songs=[]

for T in [24]:#[3,6,24]:
    for T_size in [6]:
        print('\n','-'*10,f'Dataset T:{T} T_size:{T_size}','-'*10)
        graph_data_path=os.path.join('data', 'generated', 'graphs_V4', f'full_dataset_W_{time_window_size}_T_{T}_T_size_{T_size}.graph')
        daily_dataset= torch.load(graph_data_path)
        n_snapshots=len(daily_dataset['edges'].keys())
        n_iterations= len(np.arange(0,n_snapshots-13, seq_len))

        #print(f'The number of inter-snapshot batches is {n_snapshots}')
        
        data=daily_dataset['edges'][0].clone()
        complete_data= complete_snapshot(data)
        data_time_evol= generate_new_edges_snapshot(complete_data)
        data_global= generate_all_edges_snapshot(complete_data)

        for model_type in model_types:
            results=[]

            global_loss=[]
            global_f1=[]
            global_acc=[]

            global_val_f1=[]
            global_val_acc=[]

            print('\n','-'*10, model_type, '-'*10)

            for i in tqdm(np.arange(60,200, seq_len), desc='Snapshots...', leave=False):
                print('\n',"*"*10, f'Snapshot {i}-{i+seq_len}', '*'*10)
                
                init_snapshot_date= init_date_obj + relativedelta(months=i)
                final_snapshot_date= init_date_obj + relativedelta(months=i+seq_len)
                init_snapshot_date_str= datetime.strftime(init_snapshot_date,'%Y-%m-%d')
                final_snapshot_date_str= datetime.strftime(final_snapshot_date,'%Y-%m-%d')
                print('\n',"*"*2, f'Snapshot dates {init_snapshot_date_str}:{final_snapshot_date_str}', '*'*2)

                time_horizon_init= final_snapshot_date + relativedelta(months=T)
                time_horizon_final= final_snapshot_date + relativedelta(months=T+T_size)
                time_horizon_init_str= datetime.strftime(time_horizon_init,'%Y-%m-%d')
                time_horizon_final_str= datetime.strftime(time_horizon_final,'%Y-%m-%d')
                print('\n',"*"*2, f'Prediction range {time_horizon_init_str}:{time_horizon_final_str}', '*'*2)
                
                model_loss=0
                model_f1=0
                model_acc=0

                model_val_f1=0
                model_val_acc=0

                model_max_val_f1=0
                model_max_val_acc=0

                #Create model for the new snapshot
                gnn= None
                if model_type == 'PRESTO_full':
                    gnn = HeteroEvolGNN3(node_feature_dict,  data_time_evol.metadata(), data_global.metadata(), out_channels)
                elif model_type == 'PRESTO_time_only':
                    gnn = HeteroEvolGNNWithTimeOnly(node_feature_dict,  data_time_evol.metadata(), data_global.metadata(), out_channels)
                elif model_type == 'PRESTO_agg_only':
                    gnn = HeteroEvolGNNWithAggOnly(node_feature_dict,  data_time_evol.metadata(), data_global.metadata(), out_channels)
                elif model_type=='time_only':
                    gnn= TimeEvolGNN(node_feature_dict,  data_time_evol.metadata(), out_channels)
                elif model_type == 'agg_only':
                    gnn= GlobalGNN(out_channels)
                    gnn= to_hetero(gnn,data_global.metadata())    
                elif model_type=='attention_only':
                    gnn= GlobalGNNwithAttention(out_channels)
                    gnn= to_hetero(gnn,data_global.metadata())    

                gnn= gnn.train()

                optimizer = torch.optim.Adam(gnn.parameters(), lr=0.001, weight_decay=5e-4)
                gnn= gnn.to(device)
                optimizer.zero_grad()

                for epoch in tqdm(range(0,n_epochs), desc='Epochs...'):
                    epoch_loss=0
                    epoch_f1=0
                    epoch_acc=0

                    h_dict= None
                    c_dict= None  
                    batch_loss=0

                    n_samples=0
                    n_val_samples=0

                    for j in tqdm(range(i, i+seq_len), desc='Daily...', leave=False):

                        edges= daily_dataset['edges'][j]

                        print("Completing snapshot...",end="")
                        snapshot= complete_snapshot(edges, filter_edges=True) 
                        print("DONE!")
                        
                        print("Sampling data...", end="")
                        sample_dict, sample_data= sample_heterograph_v2(snapshot)
                        print("DONE!")
                        #print(sample_data)
                        #print(sample_data.edge_index_dict[('artist', 'targetcollaborate', 'artist')])
                        #e1= sample_data.edge_index_dict[('artist', 'targetcollaborate', 'artist')][0][0]
                        #e2=sample_data.edge_index_dict[('artist', 'targetcollaborate', 'artist')][1][0]
                        #print(sample_dict['artist'], sample_dict['artist'].shape)
                        #print(e1.item(), sample_dict['artist'][e1.item()])
                        #artist_name_1, artist_pop_1= get_artist_name(e1.item(), sample_dict['artist'])
                        #artist_name_2, artist_pop_2=get_artist_name(e2.item(), sample_dict['artist'])
                        #song= get_collab_song_from_artists(e1,e2, sample_dict['artist'])
                        #print(artist_name_1, artist_pop_1, artist_name_2, artist_pop_2,song)
                        
                        y_pos_edges= sample_data.edge_index_dict[('artist', 'targetcollaborate', 'artist')]
                        y_pos_labels= sample_data.edge_label_dict[('artist', 'targetcollaborate', 'artist')]  

                        if y_pos_edges.shape[1]>0:
                            n_samples= n_samples+1

                            sample_new_edges= generate_new_edges_snapshot(sample_data)
                            sample_all_edges= generate_all_edges_snapshot(sample_data)

                            emb_, h_dict, c_dict= generate_node_embeddings(model_type, 
                                                                           gnn, 
                                                                           sample_new_edges, 
                                                                           sample_all_edges, 
                                                                           h_dict, c_dict)

                            #Generate negative edges for the batch
                            n_y_edges= y_pos_edges.shape[1]
                            n_nodes= torch.max(y_pos_edges) #snapshot['artist'].num_nodes
                            y_neg_edges, y_neg_labels = sample_negative_edges(y_pos_edges, n_nodes, n_y_edges)

                            y_edges = torch.cat([y_pos_edges, y_neg_edges], dim=1)
                            y_labels = torch.cat([y_pos_labels, y_neg_labels], dim=0)

                            edge_emb_1 =  emb_["artist"][y_edges[0]]
                            edge_emb_2 =  emb_["artist"][y_edges[1]]

                            scores= (edge_emb_1 * edge_emb_2).sum(dim=-1)
                            pred=torch.reshape(scores,(-1,1))
                            loss = loss_fn(pred, y_labels)
                            epoch_loss= loss + epoch_loss

                            pred_no_grad= pred.detach()
                            pred_sig=sigm(pred_no_grad)
                            final_pred = torch.round(pred_sig)
                            
                            f1= f1_score(y_labels, final_pred)
                            acc= accuracy_score(y_labels, final_pred)

                            epoch_f1= f1 + epoch_f1
                            epoch_acc= acc + epoch_acc

                        del snapshot
                        #del sample_data

                    epoch_loss= epoch_loss / n_samples
                    model_loss= epoch_loss.detach() + model_loss

                    epoch_f1= epoch_f1 / n_samples
                    epoch_acc= epoch_acc/ n_samples
                    model_f1= epoch_f1 + model_f1
                    model_acc= epoch_acc + model_acc

                    epoch_loss.backward(retain_graph=False)
                    optimizer.step()
                    optimizer.zero_grad(set_to_none=True)

                    with torch.no_grad(): 
                        val_edges = daily_dataset['edges'][i+seq_len]
                        #print('val_edges',val_edges.edge_index_dict[('artist', 'collaborate', 'artist')][0])
                        val_snapshot= complete_snapshot(val_edges, filter_edges=False)
                        #print('val_snapshot',val_snapshot.edge_index_dict[('artist', 'collaborate', 'artist')])
                        
                        #val_sample_data= sample_heterograph(val_snapshot)
                        val_sample_dict, val_sample_data= sample_heterograph_v2(val_snapshot)

                        #print('val_sample_data',val_sample_data.edge_index_dict[('artist', 'collaborate', 'artist')])

                        val_sample_new_edges= generate_new_edges_snapshot(val_sample_data)
                        val_sample_all_edges= generate_all_edges_snapshot(val_sample_data)


                        val_emb_, h_dict, c_dict= generate_node_embeddings(model_type, 
                                                                           gnn, 
                                                                           val_sample_new_edges, 
                                                                           val_sample_all_edges, 
                                                                           h_dict, c_dict)

                        y_val_edges= val_sample_data.edge_index_dict[('artist', 'targetcollaborate', 'artist')]
                        y_val_labels= val_sample_data.edge_label_dict[('artist', 'targetcollaborate', 'artist')]  

                        #print(y_val_edges.shape)
                        if y_val_edges.shape[1]>0:
                            n_val_samples = n_val_samples +1
                            #Generate negative edges for the batch
                            n_y_val_edges= y_val_edges.shape[1]               
                            n_nodes= torch.max(y_val_edges)             
                            y_neg_val_edges, y_neg_labels = sample_negative_edges(y_val_edges, n_nodes, n_y_val_edges)

                            #print(y_val_edges[:,1])
                            #artist_1= y_val_edges[0,1].numpy().tolist()
                            #artist_2= y_val_edges[1,1].numpy().tolist()
                            
                            #artist_name_1, artist_pop_1= get_artist_name(artist_1, val_sample_dict['artist'])
                            #artist_name_2, artist_pop_2=get_artist_name(artist_2, val_sample_dict['artist'])
                            #song= get_collab_song_from_artists(artist_1,artist_2, val_sample_dict['artist'])
                            #print(artist_name_1, artist_pop_1, artist_name_2, artist_pop_2,song)

                            y_val_edges = torch.cat([y_val_edges, y_neg_val_edges], dim=1)
                            y_val_labels = torch.cat([y_val_labels, y_neg_labels], dim=0)

                            val_edge_emb_1 =  val_emb_["artist"][y_val_edges[0]]
                            val_edge_emb_2 =  val_emb_["artist"][y_val_edges[1]]

                            val_scores= (val_edge_emb_1 * val_edge_emb_2).sum(dim=-1)
                            val_pred=torch.reshape(val_scores,(-1,1))
                            val_pred_sig=sigm(val_pred)
                            final_val_pred = torch.round(val_pred_sig)
                            
                            #Logic to show examples of collaboratons
                            l2= final_val_pred[y_val_labels >0]
                            l22= l2[l2>0]

                            e1= y_val_edges[0][y_val_labels.flatten() >0]
                            #print(e1.shape, l2.shape)
                            e1= e1[l2>0]
                            e2= y_val_edges[1][y_val_labels.flatten() >0]
                            e2= e2[l2>0]
                            #print(l22,e1,e2)
                            #print("*"*15)

                            for a_index in range(len(e1)):
                                a1_key= e1[a_index].numpy().tolist()
                                a2_key= e2[a_index].numpy().tolist()
                                artist_name_1, artist_pop_1= get_artist_name(a1_key, val_sample_dict['artist'])
                                artist_name_2, artist_pop_2=get_artist_name(a2_key, val_sample_dict['artist'])

                                if artist_pop_1 > 70 or artist_pop_2 > 70:
                                    song_lst= get_collab_song_from_artists(a1_key,a2_key, val_sample_dict['artist'])
                                    #print(a1_key, artist_name_1, artist_pop_1, a2_key, artist_name_2, artist_pop_2)
                                    if song_lst is not None:
                                        #print(song_lst)
                                        for s_index, s in song_lst.iterrows():
                                            track_to_show_id=s['track_id']
                                            release_date= s['release_date']
                                            #print(track_to_show_id, release_date)
                                            if (not track_to_show_id in displayed_songs) and (release_date >= time_horizon_init) and (release_date <= time_horizon_final):
                                                print(artist_name_1, artist_pop_1, artist_name_2, artist_pop_2, s)
                                                print("*"*10)
                                                displayed_songs.append(track_to_show_id)
                                                break

                            val_acc= accuracy_score(y_val_labels, final_val_pred)
                            val_f1= f1_score(y_val_labels, final_val_pred)

                            if val_f1 > model_val_f1:
                                model_val_f1= val_f1

                            if val_acc > model_val_acc:
                                model_val_acc= val_acc


                        #del val_loader
                        del val_snapshot
                        del val_sample_data


                    #print(f"--Epoch: {epoch:03d}, Loss: {epoch_loss:.4f}, F1: {epoch_f1:.4f}, ACC: {epoch_acc:.4f}, val-F1: {val_epoch_f1:.4f}, val-ACC: {val_epoch_acc:.4f}")

                model_f1= model_f1 / n_epochs
                model_acc= model_acc / n_epochs
                model_loss= model_loss / n_epochs

                print(f"-Model: {i:03d}, Loss: {model_loss:.4f}, F1: {model_f1:.4f}, ACC: {model_acc:.4f}, val-F1: {model_val_f1:.4f}, val-ACC: {model_val_acc:.4f}")

                global_f1.append(model_f1)
                global_loss.append(model_loss)
                global_acc.append(model_acc)

                global_val_f1.append(model_val_f1)
                global_val_acc.append(model_val_acc)

                del gnn
                del optimizer

            global_f1_mean= np.mean(global_f1)
            global_acc_mean= np.mean(global_acc)
            global_loss_mean= np.mean(global_loss)
            global_val_f1_mean= np.mean(global_val_f1)
            global_val_acc_mean= np.mean(global_val_acc)    

            global_f1_std= np.std(global_f1)
            global_acc_std= np.std(global_acc)
            global_loss_std= np.std(global_loss)
            global_val_f1_std= np.std(global_val_f1)
            global_val_acc_std= np.std(global_val_acc)  

            results.append((model_type, T, T_size, global_loss_mean, global_f1_mean, global_acc_mean,global_val_f1_mean, global_val_acc_mean, global_loss_std, global_f1_std, global_acc_std, global_val_f1_std, global_val_acc_std))
            results_df= pd.DataFrame(results, columns='model_type T T_size train_loss_mean train_f1_mean train_acc_mean val_f1_mean val_acc_mean train_loss_std train_f1_std train_acc_std val_f1_std val_acc_std'.split())
            results_df.to_csv(os.path.join('results', f'results_type_{model_type}_T_{T}_T_size_{T_size}.csv'))

            print(f"Global: {i:03d}, Loss: {global_loss_mean:.4f}, F1: {global_f1_mean:.4f}, ACC: {global_acc_mean:.4f}, val-F1: {global_val_f1_mean:.4f}, val-ACC: {global_val_acc_mean:.4f}")
# Out:
#  ---------- Dataset T:24 T_size:6 ----------
#
#  ---------- PRESTO_full ----------
# Snapshots...:   0%|          | 0/12 [00:00<?, ?it/s]
#  ********** Snapshot 60-72 **********
#
#  ** Snapshot dates 2009-01-01:2010-01-01 **
#
#  ** Prediction range 2012-01-01:2012-07-01 **
# Epochs...:   0%|          | 0/3 [00:00<?, ?it/s]
# Daily...:   0%|          | 0/12 [00:00<?, ?it/s]
# Rod Stewart 74 Michael Bublé 78 track_id        0NSAlbl5xcKOu7BKDbVk7I
# release_date       2012-01-01 00:00:00
# genres               [rock, jazz, pop]
# Name: 2906, dtype: object
# **********
# Nicki Minaj 88 Lil Wayne 88 track_id                                   6bzwoiUt0s1KDOedyy4OtQ
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, dance, pop, hip-hop, rap, trap,...
# Name: 2918, dtype: object
# **********
# Rod Stewart 74 Ella Fitzgerald 71 track_id           3MMzhB1pbabgZc51N3GzUl
# release_date          2012-01-01 00:00:00
# genres          [rock, blues, jazz, jazz]
# Name: 6294, dtype: object
# **********
# Rod Stewart 74 Chris Botti 55 track_id           0LK6y0A8mB8TLv8CG0EcfG
# release_date          2012-01-01 00:00:00
# genres          [rock, blues, jazz, jazz]
# Name: 88443, dtype: object
# **********
# Wisin & Yandel 83 Chris Brown 91 track_id                                   2FqoR7diymD1Eh7cVb3DMg
# release_date                                  2012-01-01 00:00:00
# genres          [latin, reggaeton, latino, hip-hop, electro, d...
# Name: 6355, dtype: object
# **********
# Wisin & Yandel 83 T-Pain 79 track_id                                   1m7xxL8NRP8Fp0eNYybiEa
# release_date                                  2012-01-01 00:00:00
# genres          [latin, reggaeton, latino, hip-hop, electro, d...
# Name: 1420025, dtype: object
# **********
# Owl City 71 Carly Rae Jepsen 75 track_id                   1kPpge9JDLpcj15qgrPbYX
# release_date                  2012-01-01 00:00:00
# genres          [rock, pop rock, pop, dance, pop]
# Name: 7816, dtype: object
# **********
# The Living Tombstone 73 Eurobeat Brony 59 track_id        611nlMA40SKg9gQ4pTVXT3
# release_date       2012-01-21 00:00:00
# genres                       [otacore]
# Name: 10097, dtype: object
# **********
# Booba 72 Kaaris 64 track_id                                   1ACqqQiBkxSOoEYUW57Itl
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, french, pop, trap, pop, rap, fr...
# Name: 12002, dtype: object
# **********
# Zedd 77 Foxes 63 track_id                                   60wwxj6Dd9NJlirf84wr2c
# release_date                                  2012-01-01 00:00:00
# genres          [pop, edm, rap, german, dance, house, electro,...
# Name: 13002, dtype: object
# **********
# Millonario & W. Corona 63 Cartel De Santa 81 track_id                  3NqbKUOgaU2LgIFRbu4B12
# release_date                 2012-01-17 00:00:00
# genres          [hip-hop, latin, hip-hop, latin]
# Name: 17835, dtype: object
# **********
# Rihanna 95 Mikky Ekko 71 track_id        789CxjEOtO76BVD1A9yJQH
# release_date       2012-01-01 00:00:00
# genres                    [pop, indie]
# Name: 17950, dtype: object
# **********
# Icona Pop 69 Charli XCX 78 track_id                               27ilMN1oiW9849fReEYgOj
# release_date                              2012-01-01 00:00:00
# genres          [pop, swedish, edm, dance, house, dance, pop]
# Name: 26657, dtype: object
# **********
# Pritam 89 Arijit Singh 91 track_id        6FjbAnaPRPwiP3sciEYctO
# release_date       2012-02-24 00:00:00
# genres                   [indian, pop]
# Name: 27757, dtype: object
# **********
# Maroon 5 88 Wiz Khalifa 84 track_id                       1XGmzt0PVuFgQYYnV2It7A
# release_date                      2012-01-01 00:00:00
# genres          [pop, trap, pop, rap, dance, hip-hop]
# Name: 28496, dtype: object
# **********
# Don Omar 83 Natti Natasha 76 track_id                                   2U4kPiipwfc2oHmd0nGoj5
# release_date                                  2012-01-01 00:00:00
# genres          [latin, pop, reggaeton, latino, hip-hop, latin...
# Name: 35111, dtype: object
# **********
# Rod Stewart 74 Michael Bublé 78 track_id        0vJnAIhLnRrXgtN0SmrrTy
# release_date       2012-01-01 00:00:00
# genres               [rock, jazz, pop]
# Name: 35168, dtype: object
# **********
# Don Omar 83 Natti Natasha 76 track_id                                   5Mz30xAlgBsPHWmOAPm0yJ
# release_date                                  2012-01-01 00:00:00
# genres          [latin, pop, reggaeton, latino, hip-hop, latin...
# Name: 40413, dtype: object
# **********
# Don Omar 83 Juan Magán 70 track_id                                   5fwFQ9hooBZoxdboAHo99Y
# release_date                                  2012-01-01 00:00:00
# genres          [latin, pop, reggaeton, latino, hip-hop, latin...
# Name: 47870, dtype: object
# **********
# DJ Fresh 61 Rita Ora 76 track_id                                  7uHw9gnuf6Fq8nKYFg4p1E
# release_date                                 2012-02-10 00:00:00
# genres          [dance, house, pop, pop, edm, rap, dance, house]
# Name: 62448, dtype: object
# **********
# Owl City 71 Carly Rae Jepsen 75 track_id                   5w6TVvv71F8px5cObg2xnx
# release_date                  2012-01-01 00:00:00
# genres          [rock, pop rock, pop, dance, pop]
# Name: 63615, dtype: object
# **********
# Millonario & W. Corona 63 Cartel De Santa 81 track_id                  4xbMF8jx0msGGgrtJaAuXE
# release_date                 2012-01-17 00:00:00
# genres          [hip-hop, latin, hip-hop, latin]
# Name: 68650, dtype: object
# **********
# The Living Tombstone 73 Eurobeat Brony 59 track_id        6xqJ0XqDM9dVEW1jbm78wB
# release_date       2012-01-21 00:00:00
# genres                       [otacore]
# Name: 74706, dtype: object
# **********
# Kavita Seth 67 Pritam 89 track_id               2zZTXtLqCsICzEcztKjn47
# release_date              2012-06-12 00:00:00
# genres          [hip-hop, pop, indie, indian]
# Name: 78990, dtype: object
# **********
# Nicki Minaj 88 Lil Wayne 88 track_id                                   3UrNOHCzVxX2KZbNcKQAyu
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, dance, pop, hip-hop, rap, trap,...
# Name: 105708, dtype: object
# **********
# The Game 75 Jamie Foxx 71 track_id                                   4AsRUGtyZQdSh6E8lvdlDV
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, r-n-b, pop, rap, sou...
# Name: 127219, dtype: object
# **********
# Lil Ugly Mane 51 Denzel Curry 76 track_id                            7E6GfNEX3RCq26vzS0PBly
# release_date                           2012-02-11 00:00:00
# genres          [alternative, hip-hop, hip-hop, rap, trap]
# Name: 127447, dtype: object
# **********
# Odd Future 57 Tyler, The Creator 87 track_id                                   67nRofeeMvysUeO4FxB6tL
# release_date                                  2012-03-16 00:00:00
# genres          [hip-hop, rap, alternative, hip-hop, rap, indi...
# Name: 130004, dtype: object
# **********
# Domo Genesis 58 Tyler, The Creator 87 track_id                                   4eVMZcIz4kNgeQNjlKGZbl
# release_date                                  2012-03-16 00:00:00
# genres          [hip-hop, rap, alternative, hip-hop, rap, indi...
# Name: 588354, dtype: object
# **********
# E-40 71 Too $hort 67 track_id                              29jTQkNSr0FFjhyvu4CMTU
# release_date                             2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, pop]
# Name: 131342, dtype: object
# **********
# B.o.B 75 Lil Wayne 88 track_id                                   4oNuMpBoti0wl8PJ7UbvUI
# release_date                                  2012-04-29 00:00:00
# genres          [hip-hop, rap, dance, pop, hip-hop, rap, trap,...
# Name: 131853, dtype: object
# **********
# Rick Ross 79 Ne-Yo 81 track_id                       5N8rcVUAN8f532d0ilF43W
# release_date                      2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, dance, pop]
# Name: 132065, dtype: object
# **********
# Kill The Noise 57 Skrillex 82 track_id                                   4EAizscc9Hb3LehI6K0WOJ
# release_date                                  2012-02-17 00:00:00
# genres          [rock, funk, alternative, rap, metal, electron...
# Name: 136451, dtype: object
# **********
# Dimitri Vegas & Like Mike 72 Regi 50 track_id                               2u7YhquIkjiH81u0f7XDoe
# release_date                              2012-02-28 00:00:00
# genres          [pop, edm, dance, house, electro, dance, edm]
# Name: 141088, dtype: object
# **********
# NERO 58 Calvin Harris 88 track_id                                   2ir2EueUgYtgiqpzGhCcei
# release_date                                  2012-01-01 00:00:00
# genres          [dubstep, electro, house, edm, pop, edm, dance...
# Name: 142112, dtype: object
# **********
# Skrillex 82 Kill The Noise 57 track_id                                   2ri2SrIquHGch5oXNu4oFv
# release_date                                  2012-02-17 00:00:00
# genres          [rock, funk, alternative, rap, metal, electron...
# Name: 1203654, dtype: object
# **********
# Tiësto 87 Mark Knight 60 track_id                                   1KiKgWKbnFGEteLwazvUrY
# release_date                                  2012-03-21 00:00:00
# genres          [trance, pop, edm, dance, house, edm, groove, ...
# Name: 146598, dtype: object
# **********
# Zedd 77 Matthew Koma 60 track_id                                   2oLHyxDWJVLrWXmgQBt538
# release_date                                  2012-01-01 00:00:00
# genres          [pop, edm, rap, german, dance, house, electro,...
# Name: 146776, dtype: object
# **********
# Pusha T 74 Kanye West 93 track_id                             1DbeslBYnckTqqTcc1Y2Tg
# release_date                            2012-01-01 00:00:00
# genres          [trap, pop, alternative, rap, hip-hop, rap]
# Name: 149852, dtype: object
# **********
# ZZ Ward 49 Kendrick Lamar 91 track_id        63q8MyDPEfsLZlas5oJw8Z
# release_date       2012-01-01 00:00:00
# genres                  [hip-hop, rap]
# Name: 152109, dtype: object
# **********
# Nicki Minaj 88 2 Chainz 78 track_id                                   4It00tEYLwpjQtAhqnjCPC
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, dance, pop, hip-hop, rap, trap,...
# Name: 154597, dtype: object
# **********
# Martin Garrix 80 Sleazy Stereo 46 track_id                             70JiI0UsaRZh4G5uKjJVFi
# release_date                            2012-04-09 00:00:00
# genres          [pop, edm, dance, house, electro, rap, pop]
# Name: 154810, dtype: object
# **********
# Slaughterhouse 48 B.o.B 75 track_id                               75lRWdZpydOqrDSYMu9GQt
# release_date                              2012-01-01 00:00:00
# genres          [hip-hop, rap, pop, hip-hop, rap, dance, pop]
# Name: 165187, dtype: object
# **********
# Bethel Music 72 Brian Johnson 53 track_id        46JL1Av9mRo21b4LTdD2g8
# release_date       2012-01-24 00:00:00
# genres             [ambient, deep ccm]
# Name: 169505, dtype: object
# **********
# Rick Ross 79 Drake 98 track_id                                   0nq6sfr8z1R5KJ4XUk396e
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, pop, h...
# Name: 177359, dtype: object
# **********
# Rick Ross 79 French Montana 77 track_id                                   09ip6yFP9DR5CWX51j7ulA
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, trap, ...
# Name: 192720, dtype: object
# **********
# Stafford Brothers 39 Lil Wayne 88 track_id                                   33bViaabQ8S8RoaTdoI5fj
# release_date                                  2012-01-01 00:00:00
# genres          [dance, hip-hop, rap, trap, pop, dance, hip-ho...
# Name: 181600, dtype: object
# **********
# RJ 27 Pitbull 85 track_id            4hfR0He6Oky3eGYe38iOD2
# release_date           2012-01-17 00:00:00
# genres          [hip-hop, rap, dance, pop]
# Name: 184276, dtype: object
# **********
# Juanes 78 Joaquín Sabina 71 track_id                        3zXSzgDY5Di5fLmIRom3j8
# release_date                       2012-01-01 00:00:00
# genres          [rock, latin, pop, rock, spanish, pop]
# Name: 187028, dtype: object
# **********
# Gym Class Heroes 71 Neon Hitch 49 track_id        25BU1YwIUmu6hiih7tLNUN
# release_date       2012-02-14 00:00:00
# genres          [rap, dance, pop, pop]
# Name: 187410, dtype: object
# **********
# King Charles 43 Mumford & Sons 74 track_id        7DSFu4NFVpDpWCafZ0cxPJ
# release_date       2012-01-01 00:00:00
# genres               [pop, rock, folk]
# Name: 188135, dtype: object
# **********
# Antonio Vivaldi 73 Rachel Podger 41 track_id        7mddJzxEZdgPgTxi9YYn58
# release_date       2012-06-01 00:00:00
# genres          [classical, classical]
# Name: 188283, dtype: object
# **********
# DJ Khaled 80 Rick Ross 79 track_id                                   0n0HybfiBU3YDQNVtWugtm
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, rap, hip-hop, rap, t...
# Name: 257086, dtype: object
# **********
# DJ Khaled 80 Jadakiss 67 track_id                                   7DgZtZZirPsHfHkVYkAOWk
# release_date                                  2012-05-23 00:00:00
# genres          [trap, pop, rap, hardcore, dance, hip-hop, rap...
# Name: 1942410, dtype: object
# **********
# Rick Ross 79 French Montana 77 track_id                                   26cmueXMtixyR9Q7vqZauB
# release_date                                  2012-06-22 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, trap, ...
# Name: 1336087, dtype: object
# **********
# Ab-Soul 64 Jhené Aiko 80 track_id                         15acC6GzjmD5NvpoS5jRdN
# release_date                        2012-05-11 00:00:00
# genres          [alternative, hip-hop, rap, r-n-b, pop]
# Name: 193625, dtype: object
# **********
# Ashley Wallbridge 50 Armin van Buuren 76 track_id                                   31FVKemXKLKbIxJsUn0860
# release_date                                  2012-03-08 00:00:00
# genres          [house, dance, trance, pop, trance, pop, edm, ...
# Name: 193751, dtype: object
# **********
# Steve Aoki 78 Blaqstarr 20 track_id                               0k4SPBX52UbZw4GC0cqs6E
# release_date                              2012-01-10 00:00:00
# genres          [pop, edm, rap, dance, house, electro, bmore]
# Name: 197118, dtype: object
# **********
# PJ Morton 61 Lil Wayne 88 track_id                                72RRBkYceD0A8sdBEZkbIn
# release_date                               2012-01-01 00:00:00
# genres          [gospel, soul, r-n-b, hip-hop, rap, trap, pop]
# Name: 204625, dtype: object
# **********
# E-40 71 Too $hort 67 track_id                              5aJ2yWx4guCr5rqKgt43B6
# release_date                             2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, pop]
# Name: 208064, dtype: object
# **********
# YG 77 Meek Mill 78 track_id                                   2YyQAR3DkkrGfa46fgW68q
# release_date                                  2012-05-16 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, trap, ...
# Name: 210465, dtype: object
# **********
# Kirko Bangz 54 2 Chainz 78 track_id                                   7JmaiCwcoqQmFb063jHr6y
# release_date                                  2012-05-25 00:00:00
# genres          [r-n-b, trap, pop, rap, hip-hop, hip-hop, rap,...
# Name: 214889, dtype: object
# **********
# Mack Maine 47 Lil Wayne 88 track_id                                   1N35OBiBfjjLuBMOIiIg2N
# release_date                                  2012-01-01 00:00:00
# genres          [alternative, hip-hop, hardcore, soul, hip-hop...
# Name: 218000, dtype: object
# **********
# R3HAB 79 Kaskade 69 track_id                                   1OnQmoebWQtKfYu2H5QUUp
# release_date                                  2012-01-02 00:00:00
# genres          [pop, edm, dance, house, electro, pop, edm, da...
# Name: 229178, dtype: object
# **********
# Florence + The Machine 77 AlunaGeorge 64 track_id           7fnYU6TNl03uwTsHmjy9q2
# release_date          2012-01-01 00:00:00
# genres          [alternative, pop, house]
# Name: 233350, dtype: object
# **********
# Slaughterhouse 48 Busta Rhymes 73 track_id                                  1oyz5aQv81Sx25qaCZc7MV
# release_date                                 2012-01-01 00:00:00
# genres          [hip-hop, rap, pop, hip-hop, rap, hardcore, pop]
# Name: 237550, dtype: object
# **********
# Madonna 80 Nicki Minaj 88 track_id                                   6FM1oNrcPnGMUtbopMdFvg
# release_date                                  2012-01-01 00:00:00
# genres          [dance, pop, hip-hop, rap, dance, pop, dance, ...
# Name: 243260, dtype: object
# **********
# Madonna 80 M.I.A. 69 track_id                                   03GmPu7IC3xenKdB7mXlC0
# release_date                                  2012-01-01 00:00:00
# genres          [dance, pop, hip-hop, rap, dance, pop, dance, ...
# Name: 766377, dtype: object
# **********
# Nicki Minaj 88 M.I.A. 69 track_id                                   16Ia26TpUeu4DcrDYz9BM9
# release_date                                  2012-01-01 00:00:00
# genres          [dance, pop, hip-hop, rap, dance, pop, dance, ...
# Name: 835800, dtype: object
# **********
# Fergie 72 Pitbull 85 track_id                             6POSKis0esqhzYaHY6VPkO
# release_date                            2012-01-01 00:00:00
# genres          [rap, dance, pop, hip-hop, rap, dance, pop]
# Name: 244032, dtype: object
# **********
# Owl City 71 Carly Rae Jepsen 75 track_id                           2LflnXoxOqnQGnC1GoYpaZ
# release_date                          2012-01-01 00:00:00
# genres          [rock, pop rock, pop, dance, pop, garage]
# Name: 251167, dtype: object
# **********
# Odd Future 57 Frank Ocean 86 track_id               2gEmgpnxseKEVRTwkSGopN
# release_date              2012-03-16 00:00:00
# genres          [hip-hop, rap, hip-hop, soul]
# Name: 252102, dtype: object
# **********
# Eros Ramazzotti 72 Hooverphonic 55 track_id                         11jWS3UWqUbHlKiSUkd4x8
# release_date                        2012-01-01 00:00:00
# genres          [pop, downtempo, electronica, trip hop]
# Name: 255243, dtype: object
# **********
# DJ Khaled 80 Kanye West 93 track_id                4eOJxoVUcN0kFX3ymAoREV
# release_date               2012-01-01 00:00:00
# genres          [rap, hip-hop, rap, trap, pop]
# Name: 383397, dtype: object
# **********
# DJ Khaled 80 Rick Ross 79 track_id                                   2lD4LsB3iQVnddkVM2RFAl
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, dance, r-n-b, pop, h...
# Name: 798905, dtype: object
# **********
# Kanye West 93 Rick Ross 79 track_id                                   6W64cjYNRoYydvUKqNN3Wn
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, rap, hip-hop, rap, t...
# Name: 1758924, dtype: object
# **********
# Wolfgang Amadeus Mozart 77 Marinella Pennicchi 14 track_id                                   15AJARKKFXpaMwkw2pbKrq
# release_date                                  2012-03-21 00:00:00
# genres          [classical, classical, classical, italian baro...
# Name: 264707, dtype: object
# **********
# Wolfgang Amadeus Mozart 77 Gloria Banditelli 28 track_id                                   1uXoaAvPFfqy6ppe15mUFS
# release_date                                  2012-03-21 00:00:00
# genres          [classical, classical, classical, italian baro...
# Name: 502936, dtype: object
# **********
# Wolfgang Amadeus Mozart 77 Mirko Guadagnini 10 track_id                                   2HTk0kmyKq2374qU4KiCe7
# release_date                                  2012-03-21 00:00:00
# genres          [classical, classical, classical, italian baro...
# Name: 858861, dtype: object
# **********
# Wolfgang Amadeus Mozart 77 Sergio Foresti 28 track_id                                   0ewuxxpnKlIGQBvlGfJ8AL
# release_date                                  2012-03-21 00:00:00
# genres          [classical, classical, classical, italian baro...
# Name: 1654573, dtype: object
# **********
# Cassie 65 Jeezy 73 track_id                              1c4tNQsI8EwXyS9qavR2uR
# release_date                             2012-01-01 00:00:00
# genres          [dance, r-n-b, pop, hip-hop, rap, trap, pop]
# Name: 266879, dtype: object
# **********
# Tank 59 T.I. 76 track_id                              0XHHeTdIIxDujqC1H1dYYW
# release_date                             2012-05-08 00:00:00
# genres          [r-n-b, pop, trap, pop, rap, dance, hip-hop]
# Name: 267041, dtype: object
# **********
# Wisin & Yandel 83 Franco "El Gorilla" 64 track_id                                   7y08Z9nFPI3tRy1itIogQh
# release_date                                  2012-01-01 00:00:00
# genres          [latin, reggaeton, latino, hip-hop, electro, h...
# Name: 270324, dtype: object
# **********
# Nas 76 Large Professor 49 track_id                                   3xY4TcsCUR8q0J1NgL8QK3
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, hardcore, alternative, hip-hop,...
# Name: 271105, dtype: object
# **********
# Chance the Rapper 76 VIC MENSA 62 track_id                              5sBdN0nmo9HuQ8nJoKdvmB
# release_date                             2012-04-03 00:00:00
# genres          [hip-hop, rap, pop, hip-hop, rap, trap, pop]
# Name: 274706, dtype: object
# **********
# Machine Gun Kelly 82 M Shadows 29 track_id        74xmwuNap4wOuhFzSZJnZ0
# release_date       2012-01-01 00:00:00
# genres             [hip-hop, rap, pop]
# Name: 280499, dtype: object
# **********
# Oh No 46 MF DOOM 78 track_id                              3qpdWvVGlDqVjFXDWjVf9R
# release_date                             2012-05-24 00:00:00
# genres          [alternative, hip-hop, alternative, hip-hop]
# Name: 283698, dtype: object
# **********
# Curren$y 66 Pharrell Williams 82 track_id                                   5wpDupdKxD4aKNV8kbtdYt
# release_date                                  2012-06-01 00:00:00
# genres          [alternative, hip-hop, rap, pop, hip-hop, rap,...
# Name: 287753, dtype: object
# **********
# Pitbull 85 Lil' Flip 56 track_id                                   2RlsVckjbKWVNuqPQ49olE
# release_date                                  2012-05-08 00:00:00
# genres          [hip-hop, rap, dance, pop, hip-hop, rap, trap,...
# Name: 290033, dtype: object
# **********
# David Guetta 91 Arno Cost 38 track_id                        5SQkzgMbvhvA8tI4mWa2DJ
# release_date                       2012-01-20 00:00:00
# genres          [dance, pop, edm, electro, house, edm]
# Name: 292033, dtype: object
# **********
# Obie Trice 63 Eminem 94 track_id                             0Rn3JteUwI7FUTb9z4bB4Q
# release_date                            2012-04-03 00:00:00
# genres          [hip-hop, rap, hardcore, pop, hip-hop, rap]
# Name: 293420, dtype: object
# **********
# Moby 71 Inyang Bassey 30 track_id                                1NPGJG3sOVnYeBD1mywefT
# release_date                               2012-05-01 00:00:00
# genres          [downtempo, electronica, indie, jazz, ambient]
# Name: 294828, dtype: object
# **********
# Flo Rida 81 Sia 86 track_id                             1NpW5kyvO4XrNJ3rnfcNy3
# release_date                            2012-06-22 00:00:00
# genres          [pop, edm, rap, dance, hip-hop, dance, pop]
# Name: 7446, dtype: object
# **********
# Flo Rida 81 Basto 45 track_id                                   0C6ouoHoiNjGt3nhprniPW
# release_date                                  2012-02-10 00:00:00
# genres          [pop, edm, rap, dance, hip-hop, dance, pop, po...
# Name: 298525, dtype: object
# **********
# Autoerotique 52 Tiësto 87 track_id                                   33GEcqryZ9H8CuRrZVW7UB
# release_date                                  2012-03-12 00:00:00
# genres          [electronic, electro, house, trance, pop, edm,...
# Name: 305035, dtype: object
# **********
# Nas 76 Large Professor 49 track_id                                   2OxAIHdZFMkkejthHZbye4
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, hardcore, alternative, hip-hop,...
# Name: 305491, dtype: object
# **********
# Frédéric Chopin 76 Jeffrey Noel Lastrapes 0 track_id        7ioa6OrWUpiEG1zQjFha0X
# release_date       2012-03-01 00:00:00
# genres                     [classical]
# Name: 309109, dtype: object
# **********
# Keyshia Cole 69 Lil Wayne 88 track_id                                   759b29QKmhaVSAuMp6AfWr
# release_date                                  2012-01-01 00:00:00
# genres          [r-n-b, pop, rap, dance, soul, hip-hop, rap, t...
# Name: 309173, dtype: object
# **********
# Havana Brown 49 Pitbull 85 track_id                        33tORbMH4bNhiDVKUGbqEF
# release_date                       2012-01-01 00:00:00
# genres          [dance, pop, hip-hop, rap, dance, pop]
# Name: 311376, dtype: object
# **********
# Zedd 77 Matthew Koma 60 track_id                                   6ns0pt8J6ueMREOg0H9RWt
# release_date                                  2012-01-01 00:00:00
# genres          [pop, edm, rap, german, dance, house, electro,...
# Name: 311486, dtype: object
# **********
# ScHoolboy Q 75 Jhené Aiko 80 track_id                       1j64JX3cT30zXUAz2a2C1H
# release_date                      2012-01-14 00:00:00
# genres          [hip-hop, rap, trap, pop, r-n-b, pop]
# Name: 311601, dtype: object
# **********
# Nas 76 Swizz Beatz 64 track_id                                   5R2PaGtzJCiDCTBDUcOsaJ
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, hardcore, dance, r-n-b, pop, hi...
# Name: 323332, dtype: object
# **********
# Tyga 83 Chris Richardson 30 track_id                        6Kbu55LHFZHjF2nRXVWOrd
# release_date                       2012-01-01 00:00:00
# genres          [trap, pop, rap, dance, hip-hop, idol]
# Name: 324770, dtype: object
# **********
# Bow Wow 62 T-Pain 79 track_id                                   2rXb4DkUKQghUkXGKZxxbW
# release_date                                  2012-01-01 00:00:00
# genres          [r-n-b, pop, rap, dance, hip-hop, r-n-b, pop, ...
# Name: 325666, dtype: object
# **********
# Rudimental 70 John Newman 71 track_id                            3OG0bKPHVgov24bf3UXZRh
# release_date                           2012-05-14 00:00:00
# genres          [pop, dance, house, edm, dance, pop, funk]
# Name: 327758, dtype: object
# **********
# Tiësto 87 Wolfgang Gartner 49 track_id                                   6ns18ZPBRy4B4n06cplufL
# release_date                                  2012-04-24 00:00:00
# genres          [trance, pop, edm, dance, house, electro, hous...
# Name: 329545, dtype: object
# **********
# Wale 72 Rick Ross 79 track_id                                   1BvTqJLeB9ZeGU01gFzJbh
# release_date                                  2012-03-23 00:00:00
# genres          [r-n-b, trap, pop, rap, hip-hop, hip-hop, rap,...
# Name: 330894, dtype: object
# **********
# U2 80 High Contrast 57 track_id        4uRBCmd1jNmq7Q2pV2Zuow
# release_date       2012-01-01 00:00:00
# genres                   [rock, dance]
# Name: 332957, dtype: object
# **********
# Birdman 65 Rick Ross 79 track_id                                   63hoC35mXQyygZRMQ4wcY5
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, pop, hip-hop, rap, trap, pop, h...
# Name: 334309, dtype: object
# **********
# Birdman 65 Lil Wayne 88 track_id                                   2npw9XuCQpHXM9ramYL4HR
# release_date                                  2012-02-07 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, pop, h...
# Name: 1027783, dtype: object
# **********
# Rick Ross 79 Nicki Minaj 88 track_id                                   6GOyPCfBK9RpKPp63vvQyk
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, dance, pop, trap, pop, rap, har...
# Name: 994406, dtype: object
# **********
# Rick Ross 79 Lil Wayne 88 track_id                                   4twElM431ppMx9XejgXQsc
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, dance, r-n-b, pop, h...
# Name: 1276309, dtype: object
# **********
# Nicki Minaj 88 Lil Wayne 88 track_id                                   4zlLiiUkqKMSc0BmEzSZwE
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, dance, pop, hip-hop, rap, trap,...
# Name: 953625, dtype: object
# **********
# Seether 71 Neon Feather 44 track_id                 4qmYVsXuEIwC7gSISFiPiA
# release_date                2012-01-01 00:00:00
# genres          [rock, alternative, metal, pop]
# Name: 335170, dtype: object
# **********
# The Game 75 Chris Brown 91 track_id                                   3DpqHuPTyeHWEp3lN8G0oq
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, dance, r-n-b, pop, t...
# Name: 338059, dtype: object
# **********
# The Game 75 Lil Wayne 88 track_id                                   1V9G1UraAEEDJMxXIlaZF9
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, trap, ...
# Name: 1402949, dtype: object
# **********
# Chris Brown 91 Tyga 83 track_id                                   4Hq32iErNlkKjMkiQb99jf
# release_date                                  2012-02-24 00:00:00
# genres          [trap, pop, rap, dance, hip-hop, dance, r-n-b,...
# Name: 858440, dtype: object
# **********
# Tyga 83 Lil Wayne 88 track_id                                   2NRUU0gP1d8Yif8CpsCW8l
# release_date                                  2012-01-01 00:00:00
# genres          [trap, pop, rap, dance, hip-hop, hip-hop, rap,...
# Name: 355640, dtype: object
# **********
# Union Analogtronics 8 MF DOOM 78 track_id        3BBWcBSfWwFw1sq4PUMbyI
# release_date       2012-01-31 00:00:00
# genres          [alternative, hip-hop]
# Name: 340329, dtype: object
# **********
# The Alchemist 72 Mr. Motherfucking Exquire 2 track_id             1bHGFrqD4TNqPGKXd47Dtb
# release_date            2012-06-11 00:00:00
# genres          [alternative, hip-hop, rap]
# Name: 342682, dtype: object
# **********
# Nas 76 Swizz Beatz 64 track_id                                   6voyiwXEsHp1KyEBBSURDB
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, hardcore, dance, r-n-b, pop, hi...
# Name: 343083, dtype: object
# **********
# Hannah 8 Armin van Buuren 76 track_id                  6wxuXQtKIbNLwaaDB1WBAG
# release_date                 2012-02-20 00:00:00
# genres          [trance, pop, edm, dance, house]
# Name: 344752, dtype: object
# **********
# Chief Keef 77 SD 23 track_id        3C5FoO6Nk8rYjZRmGW7hbN
# release_date       2012-03-14 00:00:00
# genres            [hip-hop, rap, trap]
# Name: 351058, dtype: object
# **********
# 2 Chainz 78 Dolla Boy 24 track_id           51qLC3ISB1Lij4d1ZIfycR
# release_date          2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop]
# Name: 351607, dtype: object
# **********
# The Alchemist 72 DRDC 2 track_id             7aIdNnGxOEwOzej6O35jYy
# release_date            2012-06-11 00:00:00
# genres          [alternative, hip-hop, rap]
# Name: 355585, dtype: object
# **********
# Tyga 83 Lil Wayne 88 track_id                                   3dnILqSmbKQvB3tZlj5glK
# release_date                                  2012-01-01 00:00:00
# genres          [trap, pop, rap, dance, hip-hop, hip-hop, rap,...
# Name: 1101096, dtype: object
# **********
# deadmau5 71 Chris James 43 track_id                               5H0CfA9GaNg0wROR9K3X3K
# release_date                              2012-05-06 00:00:00
# genres          [electronic, pop, edm, dance, house, electro]
# Name: 358579, dtype: object
# **********
# Lionel Richie 72 Blake Shelton 74 track_id        4A9vxPxWl2d0FUoj9aDmdg
# release_date       2012-01-01 00:00:00
# genres          [rock, disco, country]
# Name: 360852, dtype: object
# **********
# Yo Gotti 69 Rick Ross 79 track_id                                   78gt548qJSU0GhtZHt44RT
# release_date                                  2012-01-06 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, trap, ...
# Name: 362242, dtype: object
# **********
# The Game 75 Kanye West 93 track_id                                   1yIhFZoPNT8LcIz7n1MVHn
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, rap, alternative, ra...
# Name: 367290, dtype: object
# **********
# Grimes 72 Majical Cloudz 40 track_id        1KIb20Sgqg4XiRIPaEBwDv
# release_date       2012-02-21 00:00:00
# genres               [dance, pop, pop]
# Name: 369916, dtype: object
# **********
# Birdy 73 Mumford & Sons 74 track_id        7JWIKtAToWqvAl1qlpsjlC
# release_date       2012-01-01 00:00:00
# genres               [pop, rock, folk]
# Name: 373250, dtype: object
# **********
# Mac Miller 86 Iman Omari 52 track_id                           7s5UGKcydRmp8ljDCRheev
# release_date                          2012-03-23 00:00:00
# genres          [hip-hop, rap, alternative, indie, r-n-b]
# Name: 374391, dtype: object
# **********
# Pyotr Ilyich Tchaikovsky 71 Russian National Orchestra 50 track_id                            4L9io4XpkeysnBBbn6VH3r
# release_date                           2012-01-03 00:00:00
# genres          [classical, soundtracks, classical, piano]
# Name: 381119, dtype: object
# **********
# Wolfgang Amadeus Mozart 77 Ildebrando D'Arcangelo 38 track_id                                   6gIHPXrJwgma2o6jEKpRRJ
# release_date                                  2012-01-01 00:00:00
# genres          [classical, classical, opera, classical, class...
# Name: 382142, dtype: object
# **********
# Wolfgang Amadeus Mozart 77 Luca Pisaroni 33 track_id                                   5BotLA4JXBlK3bHYsRMkZn
# release_date                                  2012-01-01 00:00:00
# genres          [classical, classical, classical, opera, class...
# Name: 806793, dtype: object
# **********
# Wolfgang Amadeus Mozart 77 Mahler Chamber Orchestra 52 track_id                                   2DATcVxBdGcIIGd0sb1s4X
# release_date                                  2012-01-01 00:00:00
# genres          [classical, classical, opera, classical, opera...
# Name: 400496, dtype: object
# **********
# Wolfgang Amadeus Mozart 77 Yannick Nézet-Séguin 58 track_id                                0xoB34ej0o2BQU95XVxElu
# release_date                               2012-01-01 00:00:00
# genres          [classical, classical, soundtracks, classical]
# Name: 1373610, dtype: object
# **********
# Kanye West 93 DJ Khaled 80 track_id                7jCkMZdvs8ABVd7fAHyQHM
# release_date               2012-01-01 00:00:00
# genres          [rap, hip-hop, rap, trap, pop]
# Name: 944010, dtype: object
# **********
# Nicki Minaj 88 Tyga 83 track_id                                   64GxKH9f4UzKq8882oQbRB
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, dance, pop, trap, pop, rap, dan...
# Name: 387203, dtype: object
# **********
# Moby 71 Inyang Bassey 30 track_id          7xs1zUh8x0y5yOYexqxUW7
# release_date         2012-05-01 00:00:00
# genres          [downtempo, electronica]
# Name: 387896, dtype: object
# **********
# The Alchemist 72 Mayhem Lauren 4 track_id             1ZHlVgef7cYoHKvmCvWEsM
# release_date            2012-06-11 00:00:00
# genres          [alternative, hip-hop, rap]
# Name: 388170, dtype: object
# **********
# Pitbull 85 Enrique Iglesias 79 track_id                                   5uAVoXRWVEbp7Lu6VtUs63
# release_date                                  2012-01-30 00:00:00
# genres          [hip-hop, rap, dance, pop, latin, pop, pop, ed...
# Name: 392883, dtype: object
# **********
# Steve Aoki 78 Lil Jon 74 track_id                                   56hiJG52YtqUMBwiFByD68
# release_date                                  2012-01-10 00:00:00
# genres          [pop, edm, rap, dance, house, electro, hip-hop...
# Name: 396065, dtype: object
# **********
# Tyga 83 Chris Richardson 30 track_id                        3fm9CgWt7lirXh8l8p3SmD
# release_date                       2012-01-01 00:00:00
# genres          [trap, pop, rap, dance, hip-hop, idol]
# Name: 396294, dtype: object
# **********
# 2 Chainz 78 Chris Brown 91 track_id                              7fLCTKj6IzJhzfTA9AybpX
# release_date                             2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, dance, r-n-b, pop]
# Name: 398823, dtype: object
# **********
# The-Dream 67 Pusha T 74 track_id                                   5qxjA98W7L4hfemokWIWt4
# release_date                                  2012-01-01 00:00:00
# genres          [r-n-b, trap, pop, dance, hip-hop, trap, pop, ...
# Name: 402164, dtype: object
# **********
# Viktor Vaughn 57 MF DOOM 78 track_id                                   4BtScDGEkBsMV78n1m9qsz
# release_date                                  2012-01-17 00:00:00
# genres          [alternative, hip-hop, hardcore, alternative, ...
# Name: 404999, dtype: object
# **********
# Joey Bada$$ 76 Capital Steez 54 track_id         4pNT8XTKWb2vhcsqwzdXCT
# release_date        2012-06-12 00:00:00
# genres          [hip-hop, rap, hip-hop]
# Name: 406128, dtype: object
# **********
# Kid Cudi 83 MGMT 76 track_id                                   5PX4uS1LqlWEPL69phPVQQ
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, rock, alternative, dance, alter...
# Name: 410762, dtype: object
# **********
# Kid Cudi 83 Steve Aoki 78 track_id                                   6vNGAkPJqjeGSwNjbwDuTm
# release_date                                  2012-04-10 00:00:00
# genres          [pop, edm, rap, dance, house, electro, hip-hop...
# Name: 1747997, dtype: object
# **********
# Mac Miller 86 Kendrick Lamar 91 track_id                                   2w9htZtkcbR48NCWzXjfvb
# release_date                                  2012-03-23 00:00:00
# genres          [hip-hop, rap, hip-hop, rap, alternative, indi...
# Name: 410952, dtype: object
# **********
# Madonna 80 Avicii 84 track_id                    27jewQI9enBYdyBNFdH9uB
# release_date                   2012-01-01 00:00:00
# genres          [dance, pop, rap, dance, pop, edm]
# Name: 411553, dtype: object
# **********
# Antonio Vivaldi 73 Mikhail Gantvarg 23 track_id        3S3AbTzvHWgov2IKUCVOTb
# release_date       2012-03-20 00:00:00
# genres                     [classical]
# Name: 413602, dtype: object
# **********
# Antonio Vivaldi 73 The St. Petersburg Soloists 26 track_id        6d3INCbFOj0y8qZbfOmASB
# release_date       2012-03-20 00:00:00
# genres                     [classical]
# Name: 1282848, dtype: object
# **********
# Alejandro Sanz 79 Ivete Sangalo 73 track_id                                   1pb5XwXIuYAd7vZSospLXX
# release_date                                  2012-01-01 00:00:00
# genres          [rock, spanish, latin, pop, mpb, pop, funk, re...
# Name: 414626, dtype: object
# **********
# Wisin & Yandel 83 Jennifer Lopez 78 track_id                                   2RMWA3mvD4nxBR1sGF7wRp
# release_date                                  2012-01-01 00:00:00
# genres          [latin, reggaeton, latino, hip-hop, electro, r...
# Name: 419080, dtype: object
# **********
# Armin van Buuren 76 Tomas Heredia 31 track_id                                 0VX46IC6k9OdvIRMHtyoBV
# release_date                                2012-06-14 00:00:00
# genres          [trance, pop, edm, dance, house, trance, house]
# Name: 428859, dtype: object
# **********
# 2 Chainz 78 Mike Posner 72 track_id                                 0HappsAtiF5VJXo7v3jKRb
# release_date                                2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, rap, dance, pop, edm]
# Name: 430610, dtype: object
# **********
# Ab-Soul 64 Kendrick Lamar 91 track_id                           3tK9aXMLi2QSMvxAS7rpv5
# release_date                          2012-05-11 00:00:00
# genres          [alternative, hip-hop, rap, hip-hop, rap]
# Name: 433194, dtype: object
# **********
# Armin van Buuren 76 Orjan Nilsen 51 track_id                                   3HaVjlKejQmzj6hqivJ6Kv
# release_date                                  2012-03-26 00:00:00
# genres          [trance, pop, edm, dance, house, trance, pop, ...
# Name: 435620, dtype: object
# **********
# Don Omar 83 Pina Carmirelli 28 track_id                                   1uc1gbp323ObbgXeswOG4p
# release_date                                  2012-01-01 00:00:00
# genres          [latin, pop, reggaeton, latino, hip-hop, itali...
# Name: 452717, dtype: object
# **********
# Cerf 39 Armin van Buuren 76 track_id                                  6bNk6Chq7JuUZhYk7MUykf
# release_date                                 2012-06-15 00:00:00
# genres          [trance, trance, trance, pop, edm, dance, house]
# Name: 454186, dtype: object
# **********
# Cristiano Araújo 66 Israel & Rodolffo 79 track_id                  61FquQj3VyLqtF6dlrU6bY
# release_date                 2012-05-10 00:00:00
# genres          [sertanejo, pop, sertanejo, pop]
# Name: 460081, dtype: object
# **********
# Owl City 71 Carly Rae Jepsen 75 track_id                                 5iUrCJz7NDfouKNvbdESYR
# release_date                                2012-01-01 00:00:00
# genres          [rock, pop rock, pop, dance, pop, disco, house]
# Name: 460998, dtype: object
# **********
# Zedd 77 Bright Lights 47 track_id                                   2VtX9viww814jnWFERUhAS
# release_date                                  2012-01-01 00:00:00
# genres          [pop, edm, rap, german, dance, house, electro,...
# Name: 461732, dtype: object
# **********
# Rick Ross 79 Ne-Yo 81 track_id                       2mQQHvypJjsQXcZi0peW0D
# release_date                      2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, dance, pop]
# Name: 464938, dtype: object
# **********
# Keyshia Cole 69 Ashanti 73 track_id                                   2krE9iRWGexNrh15J8WVyY
# release_date                                  2012-01-01 00:00:00
# genres          [r-n-b, pop, rap, dance, soul, dance, hip-hop,...
# Name: 466192, dtype: object
# **********
# Sean Paul 82 Kelly Rowland 69 track_id                                   7tOR7egxQLBGA2cxiFFkRw
# release_date                                  2012-04-09 00:00:00
# genres          [rap, dance, pop, dancehall, r-n-b, pop, rap, ...
# Name: 466312, dtype: object
# **********
# Claude Debussy 72 Philharmonia Orchestra 65 track_id                                   7jdkXUMIfk5aZdJ9jNSQHC
# release_date                                  2012-03-12 00:00:00
# genres          [classical, british, classical, soundtracks, o...
# Name: 467157, dtype: object
# **********
# Chief Keef 77 50 Cent 85 track_id                                   3SuzCeGoNOWmbWOoDMou0B
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, hip-hop, rap, pop, trap, ...
# Name: 470216, dtype: object
# **********
# Warren G 66 Nate Dogg 78 track_id                                   0KbIwqCAHmXWu7hrszXY6j
# release_date                                  2012-04-24 00:00:00
# genres          [pop, funk, rap, hardcore, hip-hop, funk, hip-...
# Name: 476451, dtype: object
# **********
# Waka Flocka Flame 68 Nicki Minaj 88 track_id                                   119pE59HeIqBiaXHbw7B1M
# release_date                                  2012-06-08 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, dance,...
# Name: 500194, dtype: object
# **********
# Nicki Minaj 88 Tyga 83 track_id                                   673AitlQq6SZOpamDTzlPV
# release_date                                  2012-01-01 00:00:00
# genres          [trap, pop, rap, dance, hip-hop, hip-hop, rap,...
# Name: 1055042, dtype: object
# **********
# Viktor Vaughn 57 MF DOOM 78 track_id                                   1Gqj4DGyD80MinPFr67Bme
# release_date                                  2012-01-31 00:00:00
# genres          [alternative, hip-hop, hardcore, alternative, ...
# Name: 501275, dtype: object
# **********
# Voltio 57 Jowell & Randy 74 track_id                                   6l9iRzgakAc5U82eVbt8ow
# release_date                                  2012-01-23 00:00:00
# genres          [salsa, hip-hop, latin, reggaeton, latino, hip...
# Name: 507666, dtype: object
# **********
# Labrinth 81 Tinie Tempah 65 track_id                                   1rGz2fTO3UjpYfVC0QRR1a
# release_date                                  2012-04-02 00:00:00
# genres          [indie, pop, pop, edm, rap, dance, house, alte...
# Name: 511626, dtype: object
# **********
# Red Cafe 40 Jeezy 73 track_id                              28Y7pwxRJ8zhvxdXoksYJq
# release_date                             2012-01-01 00:00:00
# genres          [hip-hop, rap, pop, hip-hop, rap, trap, pop]
# Name: 516556, dtype: object
# **********
# Tiësto 87 Mark Knight 60 track_id                                   0xGTEsj7YvjvuFaOAwym2m
# release_date                                  2012-06-10 00:00:00
# genres          [trance, pop, edm, dance, house, edm, groove, ...
# Name: 523503, dtype: object
# **********
# Nicki Minaj 88 Nas 76 track_id                                   5pscnncZL1QvQKC5DWi5AW
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, dance, pop, hip-hop, rap, hardc...
# Name: 524886, dtype: object
# **********
# Nicki Minaj 88 Drake 98 track_id                                   3wu0C3Co65GCHJ2dSWGnse
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, dance, pop, hip-hop, rap, hardc...
# Name: 1205265, dtype: object
# **********
# E-40 71 Too $hort 67 track_id                              4QUmq97gvQncso9nicjppL
# release_date                             2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, pop]
# Name: 525872, dtype: object
# **********
# Estelle 67 Rick Ross 79 track_id                        1Fih2HA2NIxJyeHpZ7NHO5
# release_date                       2012-02-24 00:00:00
# genres          [r-n-b, soul, hip-hop, rap, trap, pop]
# Name: 526145, dtype: object
# **********
# Lara St. John 16 Johann Sebastian Bach 80 track_id             0qttb7Ig9aK0XO14L7JBtw
# release_date            2012-02-28 00:00:00
# genres          [violin, classical, german]
# Name: 529081, dtype: object
# **********
# The Game 75 Pusha T 74 track_id                                   1i1xJi1qUmUABLOIXVAoPA
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, trap, pop, alternati...
# Name: 530856, dtype: object
# **********
# Tiësto 87 Wolfgang Gartner 49 track_id                                   1tygoO6VWdXZM79ilOu2lc
# release_date                                  2012-04-06 00:00:00
# genres          [trance, pop, edm, dance, house, electro, hous...
# Name: 531231, dtype: object
# **********
# Jennifer Hudson 61 Ne-Yo 81 track_id                                   0XgyAhZ70xUnFpoPVEX9yM
# release_date                                  2012-04-06 00:00:00
# genres          [dance, r-n-b, soul, pop, dance, pop, hip-hop,...
# Name: 531932, dtype: object
# **********
# DJ Khaled 80 Scarface 59 track_id                                   3xI2BX87nRys1ENw1Zl0El
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, hardco...
# Name: 534043, dtype: object
# **********
# DJ Khaled 80 Nas 76 track_id                                   6S2YuqHrEfXM85jwdHm80f
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, hardco...
# Name: 1757272, dtype: object
# **********
# Cartel Mcs 43 Filipe Ret 78 track_id              0yWvpe0PVg40YK0YTRLKC8
# release_date             2012-05-08 00:00:00
# genres          [hip-hop, rap, pop, hip-hop]
# Name: 534072, dtype: object
# **********
# Amit Trivedi 75 Suraj Jagan 55 track_id                                   3xoxTMkVpRxSvOc4og4oJe
# release_date                                  2012-04-12 00:00:00
# genres          [pop, filmi, modern bollywood, folk, indian, pop]
# Name: 534882, dtype: object
# **********
# Ab-Soul 64 ScHoolboy Q 75 track_id                                   6m3W5UTTGuAu2UGBSjG6Dd
# release_date                                  2012-05-11 00:00:00
# genres          [alternative, hip-hop, rap, hip-hop, rap, trap...
# Name: 536577, dtype: object
# **********
# Justin Bieber 92 Nicki Minaj 88 track_id                         1r1yu29R4NkPPfeCZR0Ygy
# release_date                        2012-01-01 00:00:00
# genres          [pop, hip-hop, rap, dance, pop, garage]
# Name: 537600, dtype: object
# **********
# Nicki Minaj 88 Wideboys 48 track_id                         5f9c5HFRJHNYkNpfwg9LNY
# release_date                        2012-01-01 00:00:00
# genres          [pop, hip-hop, rap, dance, pop, garage]
# Name: 1325496, dtype: object
# **********
# Moby 71 John Lord Fonda 18 track_id                          5xXzueZ306nhukObb0TZVJ
# ...
# release_date                       2012-01-01 00:00:00
# genres          [hip-hop, rap, dance, pop, dance, pop]
# Name: 1777682, dtype: object
# **********
# Fragile 16 Armin van Buuren 76 track_id                  1TmvtsZT012swQwszNZkM0
# release_date                 2012-02-07 00:00:00
# genres          [trance, pop, edm, dance, house]
# Name: 1780329, dtype: object
# **********
# Maroon 5 88 Rozzi 52 track_id        7A4KjSFDx0BL75up2eK0OF
# release_date       2012-01-01 00:00:00
# genres                [pop, soul, pop]
# Name: 1782925, dtype: object
# **********
# David Guetta 91 Laidback Luke 62 track_id                                   5r1XJSAT26RClU0WxAAVfk
# release_date                                  2012-01-27 00:00:00
# genres          [dance, pop, edm, pop, edm, dance, house, elec...
# Name: 1784178, dtype: object
# **********
# Owl City 71 Carly Rae Jepsen 75 track_id                   5Xrv3rj0iGNyvwsOm3qGRs
# release_date                  2012-01-01 00:00:00
# genres          [rock, pop rock, pop, dance, pop]
# Name: 1788751, dtype: object
# **********
# Coldplay 90 Rihanna 95 track_id        2tKqZsc0epdLrsNUT6y0Ls
# release_date       2012-06-01 00:00:00
# genres                      [pop, pop]
# Name: 1796963, dtype: object
# **********
# Ellie Goulding 81 Tinie Tempah 65 track_id                                3eVKT5HX36JbtmMUFZS6rs
# release_date                               2012-01-01 00:00:00
# genres          [dance, pop, edm, pop, edm, rap, dance, house]
# Name: 1798613, dtype: object
# **********
# Dry 48 GIMS 74 track_id                                   0BU5e8rDml803bp7mbouC0
# release_date                                  2012-02-19 00:00:00
# genres          [hip-hop, french, pop, hip-hop, rap, french, pop]
# Name: 1804095, dtype: object
# **********
# Ne-Yo 81 Bob Sinclar 70 track_id                                   7qBNjRElxOnNlf1xAn5DIZ
# release_date                                  2012-01-01 00:00:00
# genres          [dance, pop, pop, edm, dance, house, disco, el...
# Name: 1805348, dtype: object
# **********
# Jennifer Lopez 78 Flo Rida 81 track_id                                  5fuIfc73negWUuLikBIQTR
# release_date                                 2012-06-22 00:00:00
# genres          [pop, edm, rap, dance, hip-hop, rap, dance, pop]
# Name: 681762, dtype: object
# **********
# Jennifer Lopez 78 Michael Woods 31 track_id                                  0LHlyOiXtZLWUJ2njUxvYA
# release_date                                 2012-01-01 00:00:00
# genres          [rap, dance, pop, pop, edm, rap, dance, hip-hop]
# Name: 1806002, dtype: object
# **********
# Johann Sebastian Bach 80 János Starker 34 track_id                                  1ZpAQ92P9zNHEUTnpbTE98
# release_date                                 2012-01-01 00:00:00
# genres          [classical, german, classical, classical, piano]
# Name: 1806094, dtype: object
# **********
# Joey Bada$$ 76 CJ Fly 51 track_id         3QbsrWxq3JyNov94VzbNdB
# release_date        2012-06-12 00:00:00
# genres          [hip-hop, rap, hip-hop]
# Name: 1806963, dtype: object
# **********
# Seether 71 Mike Olson 5 track_id            3m7B9mol9Zyb4XrXL6U4dh
# release_date           2012-01-01 00:00:00
# genres          [rock, alternative, metal]
# Name: 1809413, dtype: object
# **********
# Labrinth 81 Tinie Tempah 65 track_id                                   2mr0mqcog7JNzgO3yT34f7
# release_date                                  2012-04-02 00:00:00
# genres          [indie, pop, pop, edm, rap, dance, house, elec...
# Name: 1812340, dtype: object
# **********
# David Guetta 91 Sidney Samson 51 track_id                   1kFpXiWwpf2Dd3NTYZGIP3
# release_date                  2012-01-27 00:00:00
# genres          [dance, pop, edm, electro, house]
# Name: 1816084, dtype: object
# **********
# Kelly Rowland 69 Lil Wayne 88 track_id                                   0WjQu6qf7KlVWAb6JqICYd
# release_date                                  2012-01-01 00:00:00
# genres          [r-n-b, pop, rap, dance, soul, hip-hop, hip-ho...
# Name: 1820630, dtype: object
# **********
# Jack Johnson 78 John Cruz 44 track_id                                   6Zh7D3YcrHNo9ukyrNhxTj
# release_date                                  2012-01-01 00:00:00
# genres          [guitar, neo mellow, rock, folk, pop, country,...
# Name: 1850925, dtype: object
# **********
# The Alchemist 72 Big Twinz 4 track_id             0n10rq8o7RHEkdZc4fX4LN
# release_date            2012-06-11 00:00:00
# genres          [alternative, hip-hop, rap]
# Name: 1825344, dtype: object
# **********
# Ne-Yo 81 Seamus Haji 38 track_id            3iJrVPicGtIeheHKkdS6pG
# release_date           2012-01-01 00:00:00
# genres          [dance, pop, disco, house]
# Name: 1828475, dtype: object
# **********
# Travis Porter 59 Mike Posner 72 track_id                                 2sipz15aGBG1JZguSc57X8
# release_date                                2012-05-28 00:00:00
# genres          [hip-hop, rap, trap, pop, rap, dance, pop, edm]
# Name: 1831322, dtype: object
# **********
# The Chainsmokers 83 Priyanka Chopra 42 track_id                            7qiLJPzgKNFAM7WsSSOffu
# release_date                           2012-01-01 00:00:00
# genres          [house, dance, pop, edm, modern bollywood]
# Name: 1832584, dtype: object
# **********
# Johann Sebastian Bach 80 John Eliot Gardiner 59 track_id                                   0VGRflirooOgHHiGidYBgb
# release_date                                  2012-06-05 00:00:00
# genres          [classical, german, british, classical, classi...
# Name: 1835046, dtype: object
# **********
# E-40 71 Problem 56 track_id                                   5PR09nMAHAOOklMQMJchch
# release_date                                  2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, trap, ...
# Name: 1836085, dtype: object
# **********
# Devlin 48 Ed Sheeran 92 track_id        1N1MlRzwSKyCjfQOuI7kMj
# release_date       2012-01-01 00:00:00
# genres                    [grime, pop]
# Name: 1838509, dtype: object
# **********
# Justin Bieber 92 Ludacris 79 track_id                       1Mg8vLBYwizu7AuhYQO64V
# release_date                      2012-06-15 00:00:00
# genres          [pop, trap, pop, rap, dance, hip-hop]
# Name: 1844628, dtype: object
# **********
# Jesse & Joy 76 Pablo Alborán 77 track_id                   4QVCx0T2eF2gZb1jcvvxy3
# release_date                  2012-02-21 00:00:00
# genres          [latin, pop, spanish, latin, pop]
# Name: 1847096, dtype: object
# **********
# Grimes 72 Doldrums 27 track_id        3Kl512JPDDX8XsjagpNxlo
# release_date       2012-02-21 00:00:00
# genres             [dance, pop, indie]
# Name: 1847604, dtype: object
# **********
# Enrique Iglesias 79 R3HAB 79 track_id                                   0RVcLweMhUmFTWHlwPH9zA
# release_date                                  2012-01-01 00:00:00
# genres          [dance, pop, latin, pop, pop, edm, dance, hous...
# Name: 1857374, dtype: object
# **********
# Gudda Gudda 46 Tyga 83 track_id                                   4uSmdJyYLFo3JszNqCmnop
# release_date                                  2012-04-06 00:00:00
# genres          [hip-hop, rap, trap, trap, pop, rap, dance, hi...
# Name: 1857401, dtype: object
# **********
# Johann Sebastian Bach 80 Helmut Walcha 26 track_id                5oNrocgjX9BjM7U9RvYiNs
# release_date               2012-03-14 00:00:00
# genres          [classical, german, classical]
# Name: 1859909, dtype: object
# **********
# Yuridia 79 Armando Ávila 52 track_id                          4eE8rU7ymogVA74C8j2b2f
# release_date                         2012-06-05 00:00:00
# genres          [rock, latin, pop, ranchera, latin, pop]
# Name: 1862758, dtype: object
# **********
# Lionel Richie 72 Willie Nelson 73 track_id                                   6mw3dGENJYBDUZeHIcvLyR
# release_date                                  2012-01-01 00:00:00
# genres          [rock, disco, rock, country, singer-songwriter...
# Name: 1863554, dtype: object
# **********
# M.I.A. 69 Missy Elliott 74 track_id                                   7kuS9KLDqaHaQ1YYqUCI2z
# release_date                                  2012-01-01 00:00:00
# genres          [dance, pop, r-n-b, pop, rap, dance, hip-hop, ...
# Name: 1866269, dtype: object
# **********
# Lana Del Rey 92 Jakwob 39 track_id                  5FtPuqpCjMjkQ6hTg5rkhZ
# release_date                 2012-01-01 00:00:00
# genres          [pop, bassline, chillstep, funk]
# Name: 1866748, dtype: object
# **********
# Charlie Brown Jr. 75 Marcelo Falcão 56 track_id        7jXSzIwXdqgNABduCqgKI9
# release_date       2012-03-19 00:00:00
# genres                  [rock, reggae]
# Name: 1868432, dtype: object
# **********
# E-40 71 Too $hort 67 track_id                              4gOWnPNNX6RDMzn4B9pS8T
# release_date                             2012-01-01 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, pop]
# Name: 1871972, dtype: object
# **********
# Joey Bada$$ 76 Capital Steez 54 track_id         2PxwwqB4f9x72jbw6AgR1s
# release_date        2012-06-12 00:00:00
# genres          [hip-hop, rap, hip-hop]
# Name: 1878564, dtype: object
# **********
# Armin van Buuren 76 Judge Jules 22 track_id                                 3Z6cF5RzWrW6MAXMwjMVHg
# release_date                                2012-06-11 00:00:00
# genres          [trance, pop, edm, dance, house, trance, house]
# Name: 1887802, dtype: object
# **********
# Carly Rae Jepsen 75 Big Dog Media 19 track_id        35L7QOIRqFQ0IbOspwQcq5
# release_date       2012-01-01 00:00:00
# genres                    [dance, pop]
# Name: 1889671, dtype: object
# **********
# Maher Zain 71 Aya Zain 21 track_id          2cSsf8mBGMq3t2D1D8Chzs
# release_date         2012-04-02 00:00:00
# genres          [nasheed, rif, sholawat]
# Name: 1891636, dtype: object
# **********
# Conor Maynard 69 Rita Ora 76 track_id                           6A6xinG0jZ9FpRNA2m2MQ5
# release_date                          2012-05-28 00:00:00
# genres          [dance, pop, pop, edm, rap, dance, house]
# Name: 1894346, dtype: object
# **********
# Cartel Mcs 43 Filipe Ret 78 track_id        2bjPS0so5ajrM5bGuOTEG6
# release_date       2012-05-08 00:00:00
# genres             [hip-hop, rap, pop]
# Name: 1895186, dtype: object
# **********
# Antonio Vivaldi 73 Rachel Podger 41 track_id        1r6XbFa7zsCESrgMj8QsGQ
# release_date       2012-06-01 00:00:00
# genres          [classical, classical]
# Name: 1902396, dtype: object
# **********
# Pitbull 85 Vedo-No Shake 4 track_id            3Vd77qGGNUs4bZ7c5JTObC
# release_date           2012-05-08 00:00:00
# genres          [hip-hop, rap, dance, pop]
# Name: 1904943, dtype: object
# **********
# Eddie Vedder 64 Jack Johnson 78 track_id                             0J1iFISejodqBIy0Q9AS0N
# release_date                            2012-01-01 00:00:00
# genres          [rock, acoustic, neo mellow, acoustic, pop]
# Name: 1911681, dtype: object
# **********
# Damian Marley 68 Jack Johnson 78 track_id                3WxLFkLQUe7QXzTpZVU8zQ
# release_date               2012-01-01 00:00:00
# genres          [reggae, neo mellow, jawaiian]
# Name: 1918691, dtype: object
# **********
# The Alchemist 72 Willie The Kid Master 3 track_id             3rLc8twhnuZKNBNEoh48go
# release_date            2012-06-11 00:00:00
# genres          [alternative, hip-hop, rap]
# Name: 1921202, dtype: object
# **********
# Lana Del Rey 92 Club Clique 21 track_id        4KmtER3ibPlEHMw2CtU6Ba
# release_date       2012-01-01 00:00:00
# genres                           [pop]
# Name: 1922451, dtype: object
# **********
# Usher 81 Pharrell Williams 82 track_id                                   65czTBQkqPJwK1JAyND9Rb
# release_date                                  2012-06-12 00:00:00
# genres          [dance, hip-hop, r-n-b, pop, hip-hop, rap, dan...
# Name: 1923001, dtype: object
# **********
# N.O.R.E. 57 Busta Rhymes 73 track_id                                   1HOyLdwWlsotRkBZ7RAQWR
# release_date                                  2012-03-13 00:00:00
# genres          [hip-hop, hardcore, pop, hip-hop, rap, hardcor...
# Name: 1926892, dtype: object
# **********
# Mohan Kannan 54 Shilpa Rao 75 track_id                                  0DANTgeuWo76sVMUjQqJ9G
# release_date                                 2012-06-12 00:00:00
# genres          [indie, indian, filmi, modern bollywood, indian]
# Name: 1927562, dtype: object
# **********
# Chance the Rapper 76 Lili K 39 track_id            0RRCfVq5I4fb5FMu71Lrry
# release_date           2012-04-03 00:00:00
# genres          [hip-hop, rap, pop, r-n-b]
# Name: 1927591, dtype: object
# **********
# Javed Bashir 60 Pritam 89 track_id                                   6YH2RAfxLtO6UVfsv2LF1D
# release_date                                  2012-06-12 00:00:00
# genres          [pop, indie, indian, pop, modern bollywood, in...
# Name: 1930068, dtype: object
# **********
# ScHoolboy Q 75 Ab-Soul 64 track_id                                   4vpNOBwJSl8HA3pLXY6c8U
# release_date                                  2012-01-14 00:00:00
# genres          [hip-hop, rap, trap, pop, alternative, hip-hop...
# Name: 1934671, dtype: object
# **********
# Booba 72 Gato 45 track_id             3WdvfZarAZNvid8b9ZE8Ki
# release_date            2012-01-01 00:00:00
# genres          [hip-hop, rap, french, pop]
# Name: 1934826, dtype: object
# **********
# Waka Flocka Flame 68 Ludacris 79 track_id                                   0XTJXuorBKi9ctqgto0rAl
# release_date                                  2012-06-08 00:00:00
# genres          [hip-hop, rap, trap, pop, hip-hop, rap, trap, ...
# Name: 1936209, dtype: object
# **********
# Jennifer Lopez 78 Flo Rida 81 track_id                                  3EUE21ziEOdGPqgwdFcjlc
# release_date                                 2012-06-22 00:00:00
# genres          [pop, edm, rap, dance, hip-hop, rap, dance, pop]
# Name: 1115854, dtype: object
# **********
# MARINA 76 Evian Christ 22 track_id                  1vXxcn4W9zoXz5Gq9CIKVU
# release_date                 2012-05-08 00:00:00
# genres          [alternative, dance, pop, drain]
# Name: 1940451, dtype: object
# **********
# MIKA 69 Pharrell Williams 82 track_id                                   5tVpDaBCeJJDGS6dSlIDMM
# release_date                                  2012-01-01 00:00:00
# genres          [dance, pop, hip-hop, rap, dance, pop, electro...
# Name: 1941843, dtype: object
# **********
# Pitbull 85 Trina 58 track_id                                   1MgM0WDaoQ2A3bnIQTR6ty
# release_date                                  2012-05-08 00:00:00
# genres          [hip-hop, rap, dance, pop, r-n-b, trap, pop, r...
# Name: 1942728, dtype: object
# **********
# Ginuwine 68 Missy Elliott 74 track_id                                   4jc8McIoYuSMhnBwjydP6x
# release_date                                  2012-03-12 00:00:00
# genres          [r-n-b, pop, dance, soul, hip-hop, r-n-b, pop,...
# Name: 1944408, dtype: object
# **********
# The Alchemist 72 Danny Brown 62 track_id                                   6sc9EdZprFFMMXmn8yrLvV
# release_date                                  2012-06-11 00:00:00
# genres          [alternative, hip-hop, rap, alternative, hip-h...
# Name: 1948430, dtype: object
# **********
# John Williams 74 Philharmonische Orchester des Staatstheaters Cottbus 21 track_id        2wGBHHiJrXrPy6SjyYFICv
# release_date       2012-01-03 00:00:00
# genres                   [soundtracks]
# Name: 1949856, dtype: object
# **********
# Xzibit 68 E-40 71 track_id                                   1VKlqJjwAqPRYWrzHN2HbC
# release_date                                  2012-01-01 00:00:00
# genres          [pop, funk, rap, hardcore, hip-hop, hip-hop, r...
# Name: 1958628, dtype: object
# **********
# Ludwig van Beethoven 74 Andreas Staier 39 track_id                               0yA898HNiIH6llWWoGcOJW
# release_date                              2012-05-15 00:00:00
# genres          [classical, german, classical, german, piano]
# Name: 1959289, dtype: object
# **********
# Nas 76 Amy Winehouse 77 track_id                         4csyu5nwd3JPbQdrrubiNn
# release_date                        2012-01-01 00:00:00
# genres          [hip-hop, rap, hardcore, british, soul]
# Name: 1963060, dtype: object
# **********
# B.o.B 75 Morgan Freeman 26 track_id            591CsLWV7pXcDGqxdhskDk
# release_date           2012-04-27 00:00:00
# genres          [hip-hop, rap, dance, pop]
# Name: 1964365, dtype: object
# **********
# Daily...:   0%|          | 0/12 [00:00<?, ?it/s]

# %% [markdown]
# --------------------------------------------------------

# %%
print("That' all folks!")
